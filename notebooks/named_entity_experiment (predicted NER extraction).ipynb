# %%
import pandas as pd
import ast
pd.set_option('display.max_colwidth', 0)

import json

# %%
df = pd.read_csv("../results/ner/intron-test-public-6346-clean_with_named_entity.csv")
df_entity_ = df[df.has_entity == 1].reset_index(drop=True)

# Only consider samples with named entities and contains either location or person named entities
df_entity = df_entity_[(df_entity_.PER.notna()) | (df_entity_.LOC.notna())].reset_index(drop=True)

# %%
df_entity_.shape, df_entity.shape, df.shape
# Out:
# ((1703, 21), (1396, 21), (6346, 21))

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained(
    "masakhane/afroxlmr-large-ner-masakhaner-1.0_2.0"
)
model = AutoModelForTokenClassification.from_pretrained(
    "masakhane/afroxlmr-large-ner-masakhaner-1.0_2.0"
)
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

# %%
# All the pretrained model results are stored here
pretrained_df = pd.read_csv("../results/normalized/intron-open-test-all_models.csv")
print(pretrained_df.shape)
# Out:
# (103949, 15)

# %%
# 19 models, 5,471 samples per model
len(pretrained_df.idx.unique()), len(pretrained_df.name.unique())
# Out:
# (5471, 19)

# %%
# Only focus on sentences with named entities 
pretrained_df_entity = pretrained_df[pretrained_df["idx"].isin(df_entity["idx"].to_list())]
print(pretrained_df_entity.shape)
# Out:
# (21242, 15)

# %%
# Filtered down to 1,118 samples per model
len(pretrained_df_entity.idx.unique()), len(pretrained_df_entity.name.unique())
# Out:
# (1118, 19)

# %%
# This is finetuned model result
finetuned_df = pd.read_csv("../results/normalized/intron-open-test-all_models_finetuned.csv")
print(finetuned_df.shape)
# Out:
# (32826, 15)

# %%
# 6 finetuned models
len(finetuned_df.idx.unique()), len(finetuned_df.name.unique())
# Out:
# (5471, 6)

# %%
finetuned_df_entity = finetuned_df[finetuned_df["idx"].isin(df_entity["idx"].to_list())]
print(finetuned_df_entity.shape)
# Out:
# (6708, 15)

# %%
len(finetuned_df_entity.idx.unique()), len(finetuned_df_entity.name.unique())
# Out:
# (1118, 6)

# %%
# Replace model without prediction with empty string
pretrained_df_entity.loc[:, "prediction"] = pretrained_df_entity.loc[:, "prediction"].fillna("")
finetuned_df_entity.loc[:, "prediction"] = finetuned_df_entity.loc[:, "prediction"].fillna("")
# Out:
# /var/folders/z5/cs_w84312s1cxj7105940jzm0000gn/T/ipykernel_84864/2500601075.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pretrained_df_entity.loc[:, "prediction"] = pretrained_df_entity.loc[:, "prediction"].fillna("")
# /var/folders/z5/cs_w84312s1cxj7105940jzm0000gn/T/ipykernel_84864/2500601075.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finetuned_df_entity.loc[:, "prediction"] = finetuned_df_entity.loc[:, "prediction"].fillna("")

# %%
pretrained_df_entity.shape, finetuned_df_entity.shape
# Out:
# ((21242, 15), (6708, 15))

# %% [markdown]
# ### Extract named entities

# %%
# pretty slow

import os

n = len(pretrained_df_entity) + len(finetuned_df_entity)
save_path = f"../results/normalized/intron-open-test-all_models_filtered_ner-{n}.csv"

if not os.path.exists(save_path):
    pretrained_df_entity["entities_group_prediction"] = pretrained_df_entity.apply(lambda x: nlp.group_entities(nlp(x["prediction"])), axis=1)
    finetuned_df_entity["entities_group_prediction"] = finetuned_df_entity.apply(lambda x: nlp.group_entities(nlp(x["prediction"])), axis=1)

    pretrained_df_entity["model_tag"] = "pretrained"
    finetuned_df_entity["model_tag"] = "finetuned"
    
    all_model_entity = pd.concat([pretrained_df_entity, finetuned_df_entity], axis=0)
    all_model_entity = all_model_entity.reset_index(drop=True)
    
    all_model_entity = all_model_entity.join(df_entity[["idx", "entities_group"]].set_index("idx"), on="idx")
    
    assert n == len(all_model_entity)
    all_model_entity.to_csv(save_path, index=None)

else:
    all_model_entity = pd.read_csv(save_path)
    if "Unnamed: 0" in all_model_entity.columns:
        all_model_entity= all_model_entity.drop(columns=["Unnamed: 0"])
        
    all_model_entity.loc[:, "entities_group"] = all_model_entity["entities_group"].apply(json.loads)
    all_model_entity.loc[:, "entities_group_prediction"] = all_model_entity["entities_group_prediction"].apply(ast.literal_eval)

# %%
all_model_entity.head(2)
# Out:
#       idx   domain  gender   duration age_group   accent  \
# 0  357071  general  Female  7.258980   19-25     jaba
# 1  450381  general  Male    10.427982  19-25     ukwuani
#
#                            user_ids  \
# 0  6653712c0e2c617bfa5f8469d69c2163
# 1  062a6e856921674d55a3b54f31725f81
#
#                                                                                       audio_paths  \
# 0  /AfriSpeech-100/test/3089079d-b2ff-482e-8a5a-39c949698f5c/28f87600531493767159c4abd14b3593.wav
# 1  /AfriSpeech-100/test/ab80cd5b-cb2b-4b58-a2c4-208d20acc380/983a51e61e3e3bc34177ff4813ba96c5.wav
#
#      origin country  \
# 0  nigerian  NG
# 1  nigerian  NG
#
#                                                                                                                                              reference  \
# 0  tinubu as a game-master in politics can sacrifice personal interests for his partys win.
# 1  reuters emails and calls to grandefex went unanswered. in june 2020, germanys regulator said the platform was unauthorised and ordered its closure.
#
#                                                                                                                                                            prediction  \
# 0  tanubu as a key master in politicians has a christ personal interest for his sponsors, being first of all.
# 1  reuters emails and calls to grandfx went unanswered. full stock. in june 2020, german regulator said the plaza must unauthorize and order its closure. full stock.
#
#         wer                  name split  \
# 0  0.928571  openai/whisper-small  test
# 1  0.454545  openai/whisper-small  test
#
#                                                                                                                                                                                                                                                 entities_group_prediction  \
# 0  [{'entity_group': 'PER', 'score': 0.768043, 'word': 'tan', 'start': 0, 'end': 3}]
# 1  [{'entity_group': 'ORG', 'score': 0.9700304, 'word': 're', 'start': 0, 'end': 2}, {'entity_group': 'ORG', 'score': 0.77678293, 'word': 'grandfx', 'start': 28, 'end': 35}, {'entity_group': 'DATE', 'score': 0.99998695, 'word': 'june 2020', 'start': 68, 'end': 77}]
#
#     model_tag  \
# 0  pretrained
# 1  pretrained
#
#                                                                                                                                                                                                                                                                                                                                                                                           entities_group
# 0  [{'entity_group': 'PER', 'score': 0.9998998641967773, 'word': 'Tinubu', 'start': 0, 'end': 6}]
# 1  [{'entity_group': 'ORG', 'score': 0.999998927116394, 'word': 'Reuters', 'start': 0, 'end': 7}, {'entity_group': 'ORG', 'score': 0.9992976784706116, 'word': 'Grandefex', 'start': 28, 'end': 37}, {'entity_group': 'DATE', 'score': 0.999998152256012, 'word': 'June 2020', 'start': 58, 'end': 67}, {'entity_group': 'LOC', 'score': 0.9943286776542664, 'word': 'Germany', 'start': 69, 'end': 76}]

# %%
all_model_entity.shape, len(all_model_entity.idx.unique()), len(all_model_entity.name.unique())
# Out:
# ((27950, 18), 1118, 25)

# %% [markdown]
# ### Extract named entities for the models based on set threshold
#
# Note:
#
# The named entities for the reference is already thresholded.
# It makes sense to threshold the extracted named entities from the predicted models as well
# but this should be double-checked with the team

# %%
all_model_entity["entities_group"][0][0]
# Out:
# {'entity_group': 'PER',
#  'score': 0.9998998641967773,
#  'word': 'Tinubu',
#  'start': 0,
#  'end': 6}

# %%
all_model_entity["entities_group_prediction"][0]
# Out:
# [{'entity_group': 'PER',
#   'score': 0.768043,
#   'word': 'tan',
#   'start': 0,
#   'end': 3}]

# %%
## Extract entities

threshhold=0.8

all_model_entity.loc[:, "ner_cat"] = all_model_entity.loc[\
                                                          :, "entities_group"].apply(\
                                                          lambda x: "".join(\
                                                                            [x[i]["word"].lower().strip() \
                                                                            for i in range(len(x)) \
                                                                            if x[i]["entity_group"] == "PER" \
                                                                            or x[i]["entity_group"] == "LOC" \
                                                                            or x[i]["entity_group"] == "ORG"
                                                                            ]))

all_model_entity.loc[:, "ner_cat_prediction"] = all_model_entity.loc[\
                                                                     :, "entities_group_prediction"].apply(\
                                                                     lambda x: "".join(\
                                                                                     [x[i]["word"].lower().strip() \
                                                                                      for i in range(len(x)) \
                                                                                      if 
                                                                                      (x[i]["entity_group"] == "PER" \
                                                                                      or x[i]["entity_group"] == "LOC" \
                                                                                      or x[i]["entity_group"] == "ORG") \
                                                                                      and x[i]["score"] >= threshhold
                                                                                    ]))

# %%
len(all_model_entity.idx.unique()), \
len(all_model_entity[all_model_entity.loc[:, "ner_cat_prediction"] != ""])
# Out:
# (1118, 11602)

# %%
all_model_entity.loc[:, "ner_cat_prediction"][all_model_entity.loc[:, "ner_cat_prediction"] != ""].sample(5)
# Out:
# 20603    france
# 5539     roberthomer
# 24606    ty1nviatnam
# 23288    hong kong
# 3351     lagos
# Name: ner_cat_prediction, dtype: object

# %%
# join the entities with space
all_model_entity.loc[:, "ner_cat"] = all_model_entity.loc[:, "ner_cat"].apply(lambda x: "".join(x.split(" ")))
all_model_entity.loc[:, "ner_cat_prediction"] = all_model_entity.loc[\
                                                                     :, "ner_cat_prediction"].apply(\
                                                                     lambda x: "".join(x.split(" ")))

# %%
all_model_entity[["reference", "prediction", "ner_cat", "ner_cat_prediction", "entities_group", "entities_group_prediction"]][\
                all_model_entity.loc[:, "ner_cat_prediction"] != ""].sample(5)
# Out:
#                                                                                                               reference  \
# 17007  the government and asuu cannot hold nigerias education sector hostage because of inconclusive strike activities.
# 4336   okoroafor was watching tv as they normally do in the evening when his brother alipha went to prepare dinner.
# 25011  zangay was watching tv as they normally do in the evening when his brother aboysi went to prepare dinner.
# 5511   stylist assistant: nicoledarnella
# 10456  ijeudo came down with akajiaku disease, and was treated with ikechukwu drug at jos hospital on 09 feb, 1975
#
#                                                                                                                                      prediction  \
# 17007  the government and asu you cannot hold nigeria inspector jose because of inconsistent private security.
# 4336   okorafor was watching tv as they normally do in the evening when his brother alifa went to prepare dinner.
# 25011  zangay was watching tv as they normally do in the evening when his brother abusi went to prepare dinner.
# 5511   and the specialist assistant colonel nicole danela.
# 10456  ederjo came down with a cadac disease comer and was teted with c god work at te hospital on th ninth february come nineteen seventy five
#
#                  ner_cat ner_cat_prediction  \
# 17007  asuunigeria        nigeriajos
# 4336   okoroaforalipha    okoraforalifa
# 25011  zangayaboysi       zaabusi
# 5511   nicoledar          nicoledanela
# 10456  ijeudojoshospital  ederjo
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      entities_group  \
# 17007  [{'entity_group': 'ORG', 'score': 0.9999892115592957, 'word': 'ASUU', 'start': 19, 'end': 23}, {'entity_group': 'LOC', 'score': 0.965825080871582, 'word': 'Nigeria', 'start': 36, 'end': 43}]
# 4336   [{'entity_group': 'PER', 'score': 0.9996854066848755, 'word': 'Okoroafor', 'start': 0, 'end': 9}, {'entity_group': 'PER', 'score': 0.9999921321868896, 'word': 'Alipha', 'start': 78, 'end': 84}]
# 25011  [{'entity_group': 'PER', 'score': 0.9994913935661316, 'word': 'Zangay', 'start': 0, 'end': 6}, {'entity_group': 'PER', 'score': 0.9668879508972168, 'word': 'Aboysi', 'start': 75, 'end': 81}]
# 5511   [{'entity_group': 'PER', 'score': 0.9073049426078796, 'word': 'nicoledar', 'start': 19, 'end': 28}]
# 10456  [{'entity_group': 'PER', 'score': 0.9999923706054688, 'word': 'I', 'start': 0, 'end': 1}, {'entity_group': 'PER', 'score': 0.9766642451286316, 'word': 'jeudo', 'start': 1, 'end': 6}, {'entity_group': 'LOC', 'score': 0.5232533812522888, 'word': 'Jos', 'start': 79, 'end': 82}, {'entity_group': 'ORG', 'score': 0.9771172404289246, 'word': 'hospital', 'start': 83, 'end': 91}, {'entity_group': 'DATE', 'score': 0.999997615814209, 'word': '09 Feb, 1975', 'start': 95, 'end': 107}]
#
#                                                                                                                                                                                                                                                                                entities_group_prediction
# 17007  [{'entity_group': 'LOC', 'score': 0.9379901, 'word': 'nigeria', 'start': 39, 'end': 46}, {'entity_group': 'PER', 'score': 0.95246416, 'word': 'jos', 'start': 57, 'end': 60}]
# 4336   [{'entity_group': 'PER', 'score': 0.99926406, 'word': 'okorafor', 'start': 0, 'end': 8}, {'entity_group': 'PER', 'score': 0.99840415, 'word': 'alifa', 'start': 77, 'end': 82}]
# 25011  [{'entity_group': 'PER', 'score': 0.99708146, 'word': 'za', 'start': 0, 'end': 2}, {'entity_group': 'PER', 'score': 0.6608591, 'word': 'ngay', 'start': 2, 'end': 6}, {'entity_group': 'PER', 'score': 0.84516317, 'word': 'abusi', 'start': 75, 'end': 80}]
# 5511   [{'entity_group': 'PER', 'score': 0.99471176, 'word': 'nicole danela', 'start': 37, 'end': 50}]
# 10456  [{'entity_group': 'PER', 'score': 0.8898059, 'word': 'ederjo', 'start': 0, 'end': 6}, {'entity_group': 'DATE', 'score': 0.9741936, 'word': 'ninth february come', 'start': 95, 'end': 114}, {'entity_group': 'DATE', 'score': 0.9561, 'word': 'nineteen seventy five', 'start': 115, 'end': 136}]

# %%
df_names = pd.read_csv("../data/African_names/List of Nigerian names - Sheet1.csv")
df_names2 = pd.read_csv("../data/African_names/mmc2-igbo names.csv", delimiter=";")
df_names3 = pd.read_csv("../data/African_names/AfricanNamesDatabase.csv")
df_names_list = df_names.YORUBA.str.lower().to_list() + df_names.HAUSA.str.lower().to_list()+ \
                    df_names.IBO.str.lower().to_list() + df_names2["Igbo Names"].str.lower().to_list() 
#                    + \ df_names3.Name.str.lower().to_list()
df_names_list = df_names_list
print(len(df_names_list))

# afri ner
all_model_entity.loc[:, "afri_ner_cat"] = all_model_entity.loc[\
                                                               :, "entities_group"].apply(\
                                                                lambda x: "".join(\
                                                                [j.lower().strip() \
                                                                for i in range(len(x)) \
                                                                if x[i]["entity_group"] == "PER" \
                                                                for j in x[i]["word"].split()
                                                                if j.lower() in df_names_list]
                                                               ))
all_model_entity.loc[:, "afri_ner_cat_prediction"] = all_model_entity.loc[\
                                                                        :, "entities_group_prediction"].apply(\
                                                                        lambda x: "".join(\
                                                                        [j.lower().strip() \
                                                                        for i in range(len(x)) \
                                                                        if x[i]["entity_group"] == "PER" \
#                                                                         if x[i]["word"].lower() in df_names_list]
                                                                        for j in x[i]["word"].split()
                                                                        if j.lower() in df_names_list]
                                                                        ))



all_model_entity.loc[:, "afri_ner_cat"] = all_model_entity.loc[\
                                                               :, "afri_ner_cat"].apply(\
                                                               lambda x: "".join(x.split(" ")))
all_model_entity.loc[:, "afri_ner_cat_prediction"] = all_model_entity.loc[\
                                                                          :, "afri_ner_cat_prediction"].apply(\
                                                                          lambda x: "".join(x.split(" ")))

# df_entity_PER.loc[:, "afri_ner_count"] = df_entity_PER.loc[:, "entities_group"].
# apply(lambda x: len([x[i]["word"] for i in range(len(x)) if x[i]["entity_group"] == "PER" 
#                      if x[i]["word"].lower() in df_names_list]))


all_model_entity.loc[:, "afri_ner_count"] = all_model_entity.loc[:, "entities_group"].apply(\
                                            lambda x: len([j \
                                            for i in range(len(x)) \
                                            if x[i]["entity_group"] == "PER" \
                                            for j in x[i]["word"].split()
                                            if j.lower() in df_names_list]
#                                             if x[i]["word"].lower() in df_names_list]             
                                            ))

all_model_entity.loc[:, "afri_ner"] = all_model_entity.loc[:, "entities_group"].apply(\
                                            lambda x: [j \
                                            for i in range(len(x)) \
                                            if x[i]["entity_group"] == "PER" \
                                            for j in x[i]["word"].split()
                                            if j.lower() in df_names_list]
#                                             if x[i]["word"].lower() in df_names_list]             
                                            )
# Out:
# 2462

# %%
len(all_model_entity[all_model_entity.loc[:, "afri_ner_cat"] != ""].idx.unique()), \
len(all_model_entity[all_model_entity.loc[:, "afri_ner_cat_prediction"] != ""])
# Out:
# (263, 826)

# %%
len(all_model_entity[all_model_entity["afri_ner_count"] >= 1].idx.unique())
# Out:
# 263

# %%
xx = all_model_entity[all_model_entity.loc[:, "afri_ner_count"] >= 1]
xx = xx[~xx.duplicated(subset=["idx"])]
xx.afri_ner_count.sum()
# Out:
# 415

# %%
xx[["reference", "prediction", "entities_group", "entities_group_prediction", "afri_ner", "afri_ner_count"]].sample(5)
# Out:
#                                                                                                                                                               reference  \
# 533   here is a 22 yr old food poisoning patient aiyeku kamiye who presented to clinic at 11am this morning
# 1098  golibe ogomegbunam other antimalarial drugs include pyrimethamine, proguanil, chlorproguanil, and trimethoprim
# 1031  dr arinola aderiyike speaking. next line. chief complaints: next line. patient had fever, generalized body pain, and bitter taste for 2 weeks duration
# 694   seeing how the ghost of museveni was walking majestically round the balogun stadium, the buhari group was said to have ran round to jerk the slush fund to 3,000.
# 934   it is widely believed that in order to understand the present, you need to examine the past - magani molayo
#
#                                                                                                                                                                  prediction  \
# 533   here is a 22 year old food poisoning patient, ayaku kamiye who presented the clinic at 11 am this morning.
# 1098  go live or go may goonum. other anti-malarial drugs include pyromethamine progarnil cloprogarnil and trimetoprim.
# 1031  dr. arinola adiriake speaking., next slide., cheap complaint, calling, next slide., patient heart fever, generalised body pain, and beta test for two weeks duration.
# 694   seeing how the ghost of missy venny was walking madesi kali round the balogu stadium, the buhari group was said to have ran around to check the slush fund to 3,000.
# 934   it is widely believed that in order to understand the present, you need to examine the past. i think, magani moliow.
#
#                                                                                                                                                                                                                                                                                                                                                                                                           entities_group  \
# 533   [{'entity_group': 'DATE', 'score': 0.9999859929084778, 'word': '22 yr old', 'start': 10, 'end': 19}, {'entity_group': 'PER', 'score': 0.9999983310699463, 'word': 'A', 'start': 43, 'end': 44}, {'entity_group': 'PER', 'score': 0.9229534268379211, 'word': 'iyeku Kamiye', 'start': 44, 'end': 56}, {'entity_group': 'DATE', 'score': 0.9999083876609802, 'word': '11am this morning', 'start': 84, 'end': 101}]
# 1098  [{'entity_group': 'PER', 'score': 0.9999161958694458, 'word': 'Golibe Ogomegbunam', 'start': 0, 'end': 18}]
# 1031  [{'entity_group': 'PER', 'score': 0.9999995231628418, 'word': 'A', 'start': 3, 'end': 4}, {'entity_group': 'PER', 'score': 0.9999728202819824, 'word': 'rinola Aderiyike', 'start': 4, 'end': 20}, {'entity_group': 'DATE', 'score': 0.9999878406524658, 'word': '2 weeks', 'start': 134, 'end': 141}]
# 694   [{'entity_group': 'PER', 'score': 0.9999949932098389, 'word': 'Museveni', 'start': 24, 'end': 32}, {'entity_group': 'LOC', 'score': 0.9999313354492188, 'word': 'Balogun Stadium', 'start': 68, 'end': 83}, {'entity_group': 'PER', 'score': 0.9996496438980103, 'word': 'Buhari', 'start': 89, 'end': 95}]
# 934   [{'entity_group': 'PER', 'score': 0.9997414946556091, 'word': 'Magani Molayo', 'start': 94, 'end': 107}]
#
#                                                                                                                                                                                                                                                                                                                                                 entities_group_prediction  \
# 533   [{'entity_group': 'DATE', 'score': 0.99999446, 'word': '22 year old', 'start': 10, 'end': 21}, {'entity_group': 'PER', 'score': 0.99974054, 'word': 'ayaku kamiye', 'start': 46, 'end': 58}, {'entity_group': 'DATE', 'score': 0.9999529, 'word': '11 am this morning', 'start': 87, 'end': 105}]
# 1098  []
# 1031  [{'entity_group': 'PER', 'score': 0.999998, 'word': 'a', 'start': 4, 'end': 5}, {'entity_group': 'PER', 'score': 0.9938493, 'word': 'rinola adiriake', 'start': 5, 'end': 20}, {'entity_group': 'DATE', 'score': 0.9999947, 'word': 'two weeks', 'start': 146, 'end': 155}]
# 694   [{'entity_group': 'PER', 'score': 0.9252866, 'word': 'miss venny', 'start': 24, 'end': 35}, {'entity_group': 'LOC', 'score': 0.99739695, 'word': 'balogu stadium', 'start': 70, 'end': 84}, {'entity_group': 'PER', 'score': 0.7316538, 'word': 'bu', 'start': 90, 'end': 92}, {'entity_group': 'ORG', 'score': 0.5671392, 'word': 'hari', 'start': 92, 'end': 96}]
# 934   []
#
#                    afri_ner  afri_ner_count
# 533   [Kamiye]               1
# 1098  [Golibe, Ogomegbunam]  2
# 1031  [Aderiyike]            1
# 694   [Buhari]               1
# 934   [Magani, Molayo]       2

# %%
all_model_entity[["reference", "prediction", "afri_ner_cat", "afri_ner_cat_prediction", "entities_group", "entities_group_prediction"]][\
                all_model_entity.loc[:, "afri_ner_cat_prediction"] != ""].sample(5)
# Out:
#                                                                                                                                                                      reference  \
# 26659  fu appointement for pt jinmi with dr. ebube udumma scheduled for wednesday, 28-12-2003
# 314    nnanna was watching tv as they normally do in the evening when his brother chimaihe went to prepare dinner.
# 24921  children kilani ali and ejefenihu were found last night wandering the streets unattended after their mother and father, went missing while returning from work at minna
# 23082  this morning efe came to arinola hospital in iwo to see dr ilemobola
# 9310   the elderly clergy man, revd ozichi chisimdi developed a heart attack
#
#                                                                                                                                                                   prediction  \
# 26659  fu appointement for pt jimmi with dr. ebube uduma schetuled for wednesday, 28-12-2003
# 314    nana was watching tv as they normally do in the evening when his brother, chima ihei, went to prepare dinner.
# 24921  children kilani ale and ejefenihi were found last night onderin the streets unattended after their mother and father, went missing while returning from work at minna
# 23082  this morning efe came to arinola hospital in iwo to see dr ilemobola
# 9310   the elderly clergyman kama reverend ozichi shizumdi developed a heart attack
#
#            afri_ner_cat afri_ner_cat_prediction  \
# 26659  jinmiebubeudumma  ebubeuduma
# 314    chimaihe          chima
# 24921  kilaniali         kilani
# 23082  ilemobola         ilemobola
# 9310   ozichichisimdi    ozichi
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       entities_group  \
# 26659  [{'entity_group': 'PER', 'score': 0.9999573826789856, 'word': 'Jinmi', 'start': 23, 'end': 28}, {'entity_group': 'PER', 'score': 0.9995142817497253, 'word': 'Ebube Udumma', 'start': 38, 'end': 50}, {'entity_group': 'DATE', 'score': 0.9999926686286926, 'word': 'Wednesday, 28-12-2003', 'start': 65, 'end': 86}]
# 314    [{'entity_group': 'PER', 'score': 0.99981290102005, 'word': 'N', 'start': 0, 'end': 1}, {'entity_group': 'PER', 'score': 0.8267667293548584, 'word': 'nanna', 'start': 1, 'end': 6}, {'entity_group': 'PER', 'score': 0.9990871548652649, 'word': 'Chimaihe', 'start': 75, 'end': 83}]
# 24921  [{'entity_group': 'PER', 'score': 0.9999977946281433, 'word': 'Kilani Ali', 'start': 9, 'end': 19}, {'entity_group': 'PER', 'score': 0.9999982118606567, 'word': 'E', 'start': 24, 'end': 25}, {'entity_group': 'PER', 'score': 0.9544576406478882, 'word': 'jefenihu', 'start': 25, 'end': 33}, {'entity_group': 'DATE', 'score': 0.9998205900192261, 'word': 'last night', 'start': 45, 'end': 55}, {'entity_group': 'LOC', 'score': 0.9930636882781982, 'word': 'Minna', 'start': 162, 'end': 167}]
# 23082  [{'entity_group': 'DATE', 'score': 0.9754523038864136, 'word': 'This morning', 'start': 0, 'end': 12}, {'entity_group': 'PER', 'score': 0.9988852739334106, 'word': 'Efe', 'start': 13, 'end': 16}, {'entity_group': 'ORG', 'score': 0.9987178444862366, 'word': 'Arinola hospital', 'start': 25, 'end': 41}, {'entity_group': 'LOC', 'score': 0.9627955555915833, 'word': 'Iwo', 'start': 45, 'end': 48}, {'entity_group': 'PER', 'score': 0.9999983906745911, 'word': 'Ilemobola', 'start': 59, 'end': 68}]
# 9310   [{'entity_group': 'PER', 'score': 0.9999967813491821, 'word': 'Ozichi Chisimdi', 'start': 29, 'end': 44}]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                          entities_group_prediction
# 26659  [{'entity_group': 'PER', 'score': 0.9985395, 'word': 'jimmi', 'start': 23, 'end': 28}, {'entity_group': 'PER', 'score': 0.9717724, 'word': 'ebube uduma', 'start': 38, 'end': 49}, {'entity_group': 'DATE', 'score': 0.99999785, 'word': 'we', 'start': 64, 'end': 66}, {'entity_group': 'DATE', 'score': 0.997343, 'word': 'dnesday, 28-12-2003', 'start': 66, 'end': 85}]
# 314    [{'entity_group': 'PER', 'score': 0.99978006, 'word': 'chima ihei', 'start': 74, 'end': 84}]
# 24921  [{'entity_group': 'PER', 'score': 0.9852264, 'word': 'kilani ale', 'start': 9, 'end': 19}, {'entity_group': 'PER', 'score': 0.9989297, 'word': 'e', 'start': 24, 'end': 25}, {'entity_group': 'PER', 'score': 0.9246713, 'word': 'jefenihi', 'start': 25, 'end': 33}, {'entity_group': 'DATE', 'score': 0.98987144, 'word': 'last night', 'start': 45, 'end': 55}, {'entity_group': 'LOC', 'score': 0.99964964, 'word': 'minna', 'start': 160, 'end': 165}]
# 23082  [{'entity_group': 'DATE', 'score': 0.95522094, 'word': 'this morning', 'start': 0, 'end': 12}, {'entity_group': 'PER', 'score': 0.9178558, 'word': 'ilemobola', 'start': 59, 'end': 68}]
# 9310   [{'entity_group': 'PER', 'score': 0.97836924, 'word': 'ozichi shizumdi', 'start': 36, 'end': 51}]

# %%
# some words in predicted afri entities but not in reference
# for example, reference has "al-mustapha" which is predicted as mustapha
# mustapha exist in our list but mustapha does not.
# df_names_list.index("mustafa")  vs "mustapha"

# %%
# df_names_list.index("bashir")

# %% [markdown]
# ### Compute metric

# %%
from datasets import load_metric
wer_metric = load_metric("wer")
cer_metric = load_metric("cer")
# Out:
# /var/folders/z5/cs_w84312s1cxj7105940jzm0000gn/T/ipykernel_84864/2617036738.py:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   wer_metric = load_metric("wer")

# %%
len(all_model_entity[(all_model_entity.name == "openai/whisper-large") & (all_model_entity.domain == "clinical")])
# Out:
# 147

# %%
# Sanity check

x = all_model_entity[(all_model_entity.name == "openai/whisper-large") & (all_model_entity.domain == "clinical")]
print(wer_metric.compute(predictions=x.prediction, references=x.reference))

x = all_model_entity[(all_model_entity.name == "openai/whisper-large") & (all_model_entity.domain == "general")]
print(wer_metric.compute(predictions=x.prediction, references=x.reference))

x = all_model_entity[all_model_entity.name == "openai/whisper-large"]
print(wer_metric.compute(predictions=x.prediction, references=x.reference))
# Out:
# 0.5388821385176185
# 0.30014974211080914
# 0.32011993698226354

# %%
x = all_model_entity[(all_model_entity.name == "openai/whisper-large") & (all_model_entity.domain == "clinical")]
print(cer_metric.compute(predictions=x.prediction, references=x.reference))

x = all_model_entity[(all_model_entity.name == "openai/whisper-large") & (all_model_entity.domain == "general")]
print(cer_metric.compute(predictions=x.prediction, references=x.reference))

x = all_model_entity[all_model_entity.name == "openai/whisper-large"]
print(cer_metric.compute(predictions=x.prediction, references=x.reference))
# Out:
# 0.2403334337651903
# 0.14382112160983127
# 0.1519860656782361

# %%
# Sanity check

x = all_model_entity[(all_model_entity.name == "openai/whisper-large") & (all_model_entity.domain == "clinical")]
print(cer_metric.compute(predictions=x.ner_cat_prediction, references=x.ner_cat))

x = all_model_entity[(all_model_entity.name == "openai/whisper-large") & (all_model_entity.domain == "general")]
print(cer_metric.compute(predictions=x.ner_cat_prediction, references=x.ner_cat))

x = all_model_entity[all_model_entity.name == "openai/whisper-large"]
print(cer_metric.compute(predictions=x.ner_cat_prediction, references=x.ner_cat))
# Out:
# 0.8412371134020619
# 0.5650354738948518
# 0.5874289535272484

# %%
def domain_wer(df, metric="wer", columns=None, sort_by=None, predictions="ner_cat_prediction", references="ner_cat"):
    
    if columns is None:
        columns = [
                ("Test (baseline)", "General"), ("Test (baseline)", "Clinical"), ("Test (baseline)", "Both"), \
               ("Test (without ner)", "General"), ("Test (without ner)", "Clinical"), ("Test (without ner)", "Both"), \
                ("Test (ner)", "General"), ("Test (ner)", "Clinical"), ("Test (ner)", "Both"), \
                ("Test (ner ng)", "General"), ("Test (ner ng)", "Clinical"), ("Test (ner ng)", "Both"),
             ]
    
    if sort_by is None:
        sort_by = ("Test (ner)", "Both")
        
    df = df.copy()
    df.domain = df.domain.str.capitalize()
    df.split = df.split.str.capitalize()
    
    
    # compute the domain WER
    if metric == "cer":
        domain_df = df.groupby(["model_tag", "name", "split", "domain"]).apply(lambda x: cer_metric.compute(predictions=x[predictions], references=x[references]))        
        domain_df_ = df.groupby(["model_tag", "name", "split"]).apply(lambda x: cer_metric.compute(predictions=x[predictions], references=x[references])).reset_index()
    
    elif metric=="wer":
        domain_df = df.groupby(["model_tag", "name", "split", "domain"]).apply(lambda x: wer_metric.compute(predictions=x[predictions], references=x[references]))
        domain_df_ = df.groupby(["model_tag", "name", "split"]).apply(lambda x: wer_metric.compute(predictions=x[predictions], references=x[references])).reset_index()
        
    _domain_df = domain_df.reset_index().set_index(["model_tag", "name"]).pivot(columns=["split", "domain"])
    _domain_df = _domain_df.droplevel(0, axis=1)
        
    domain_df_["domain"] = "Both"    
    domain_df_ = domain_df_.set_index(["model_tag", "name"]).pivot(columns=["split", "domain"])
    domain_df_ = domain_df_.droplevel(0, axis=1)
    
    # merge
    domain_df__ = _domain_df.merge(domain_df_, on=["model_tag", "name"]).sort_values(sort_by)    
    domain_df__ = domain_df__[columns]
    domain_df__ = domain_df__.round(3)
    domain_df__.columns.names = ["", ""]
    return domain_df__

# %%
all_model_entity.columns
# Out:
# Index(['idx', 'domain', 'gender', 'duration', 'age_group', 'accent',
#        'user_ids', 'audio_paths', 'origin', 'country', 'reference',
#        'prediction', 'wer', 'name', 'split', 'entities_group_prediction',
#        'model_tag', 'entities_group', 'ner_cat', 'ner_cat_prediction',
#        'afri_ner_cat', 'afri_ner_cat_prediction', 'afri_ner_count',
#        'afri_ner'],
#       dtype='object')

# %%
split = "Test (ner -- wer)"
all_model_entity["split"] = split

columns = [(split, "General"), (split, "Clinical"), (split, "Both")]
sort_by = (split, "General")

domain_df = domain_wer(all_model_entity, 
                       metric="wer", 
                       columns=columns, 
                       sort_by=sort_by, 
                       references="reference",
                       predictions="prediction")
domain_df
# Out:
#                                                             Test (ner -- wer)  \
#                                                                       General
# model_tag  name
# finetuned  openai/whisper-medium-general                     0.198
#            openai/whisper-medium-all                         0.208
#            facebook/wav2vec2-large-xlsr-53-english-general   0.258
# pretrained openai/whisper-large                              0.300
# finetuned  facebook/wav2vec2-large-xlsr-53-english-all       0.302
# pretrained openai/whisper-medium                             0.352
#            openai/whisper-medium-en                          0.388
#            Azure                                             0.402
#            openai/whisper-small                              0.405
#            AWS                                               0.426
#            openai/whisper-small-en                           0.430
# finetuned  facebook/wav2vec2-large-xlsr-53-english-clinical  0.464
# pretrained AWS [Medical] (Primary Care)                      0.514
# finetuned  openai/whisper-medium-clinical                    0.516
# pretrained facebook/wav2vec2-large-xlsr-53-english           0.550
#            facebook/wav2vec2-xls-r-1b-english                0.568
#            facebook/wav2vec2-large-960h-lv60-self            0.584
#            GCP                                               0.603
#            facebook/hubert-large-ls960-ft                    0.607
#            facebook/hubert-xlarge-ls960-ft                   0.613
#            GCP [Medical]                                     0.618
#            microsoft/wavlm-libri-clean-100h-large            0.680
#            facebook/wav2vec2-large-960h                      0.696
#            facebook/wav2vec2-large-robust-ft-swbd-300h       0.796
#            microsoft/wavlm-libri-clean-100h-base             0.830
#
#
#                                                             Clinical   Both
# model_tag  name
# finetuned  openai/whisper-medium-general                     0.575    0.230
#            openai/whisper-medium-all                         0.304    0.216
#            facebook/wav2vec2-large-xlsr-53-english-general   0.541    0.282
# pretrained openai/whisper-large                              0.539    0.320
# finetuned  facebook/wav2vec2-large-xlsr-53-english-all       0.388    0.310
# pretrained openai/whisper-medium                             0.595    0.373
#            openai/whisper-medium-en                          0.574    0.403
#            Azure                                             0.597    0.418
#            openai/whisper-small                              0.696    0.429
#            AWS                                               0.696    0.448
#            openai/whisper-small-en                           0.594    0.444
# finetuned  facebook/wav2vec2-large-xlsr-53-english-clinical  0.410    0.460
# pretrained AWS [Medical] (Primary Care)                      0.682    0.528
# finetuned  openai/whisper-medium-clinical                    0.392    0.506
# pretrained facebook/wav2vec2-large-xlsr-53-english           0.742    0.566
#            facebook/wav2vec2-xls-r-1b-english                0.795    0.587
#            facebook/wav2vec2-large-960h-lv60-self            0.831    0.605
#            GCP                                               0.726    0.613
#            facebook/hubert-large-ls960-ft                    0.866    0.629
#            facebook/hubert-xlarge-ls960-ft                   0.892    0.637
#            GCP [Medical]                                     0.706    0.625
#            microsoft/wavlm-libri-clean-100h-large            0.911    0.699
#            facebook/wav2vec2-large-960h                      0.942    0.717
#            facebook/wav2vec2-large-robust-ft-swbd-300h       1.050    0.817
#            microsoft/wavlm-libri-clean-100h-base             0.982    0.843

# %%
all_model_entity[all_model_entity.loc[:, "afri_ner_count"] >= 1]
# Out:
#           idx   domain  gender   duration age_group         accent  \
# 0      357071  general  Female  7.258980   19-25     jaba
# 2      421195  general  Female  8.366984   19-25     igbo
# 3      307962  general  Female  8.720998   26-40     oklo
# 6      312469  general  Male    5.360000   56yrs>    igbo
# 9      310476  general  Male    7.816984   19-25     kalabari
# ...       ...      ...   ...         ...     ...          ...
# 27931  575112  general  Other   16.961000  41-55     yoruba, hausa
# 27932  594568  general  Male    9.430000   41-55     eggon
# 27938  613596  general  Male    16.677000  19-25     yala mbembe
# 27941  828544  general  Male    14.237000  19-25     ekpeye
# 27949  712100  general  Female  16.147000  19-25     ibibio
#
#                                user_ids  \
# 0      6653712c0e2c617bfa5f8469d69c2163
# 2      803297b4bbd524fa708a18f3f117b79e
# 3      0025a3634a3f45e792d1567b9cdcd246
# 6      a1dd0007687f8c1a5a22e67fc8edbb64
# 9      5328a1cc3e8a8bb87e9736e5201f8c1a
# ...                                 ...
# 27931  3f7402dad2ccf1d2f93f931d41ddb72c
# 27932  33e28feaae9e298e95471515415a233d
# 27938  b2043f0c05b1d68b6c7194e78247da8d
# 27941  9dc1431272e68c73d54ad310595bed50
# 27949  5856f88ae52888c338fe3ac15d673849
#
#                                                                                           audio_paths  \
# 0      /AfriSpeech-100/test/3089079d-b2ff-482e-8a5a-39c949698f5c/28f87600531493767159c4abd14b3593.wav
# 2      /AfriSpeech-100/test/ee3a0205-d73d-4890-9c4f-bb29a38e5181/1f6f931ca80ef5f8fad73a4e5649f0db.wav
# 3      /AfriSpeech-100/test/b6c84a08-7e3a-4cf9-ac28-3ff9cbfde3df/388f79f5b4b8de8bda91223cff67c06f.wav
# 6      /AfriSpeech-100/test/693814b9-21be-49b2-9644-731fad0c2003/10c9abe5ca5dbe03fb8f54cd4d80ab7f.wav
# 9      /AfriSpeech-100/test/e7e5f40f-be39-4473-9f41-b46a5f014c66/3ef1f7240d84bc9ab466da9829b38721.wav
# ...                                                                                               ...
# 27931  /AfriSpeech-100/test/1f5803ce-28f6-4ef4-b4d9-c40e974904bb/e9873957c35ebb74325b330bda5eba1a.wav
# 27932  /AfriSpeech-100/test/4253c742-9ae2-4c29-b7c1-953e9742c0e2/ca22a37fbd640ff2733a10a640cb5c2b.wav
# 27938  /AfriSpeech-100/test/69150ad5-a088-48bb-b0a4-1beb29aa4aeb/09ddea703a7a7fc505d662bc5ae77a8c.wav
# 27941  /AfriSpeech-100/test/482541f2-75d4-4b3a-9db6-2dea5b16bd81/b9035f5a84ba9c6273052b5aaea69158.wav
# 27949  /AfriSpeech-100/test/76521f8a-6968-4ba7-ac3f-e4580e5f3b29/2e8c7964aceb4c3ba9e10182052617cb.wav
#
#          origin country  ...              split  \
# 0      nigerian  NG      ...  Test (ner -- wer)
# 2      nigerian  NG      ...  Test (ner -- wer)
# 3      nigerian  NG      ...  Test (ner -- wer)
# 6      nigerian  NG      ...  Test (ner -- wer)
# 9      nigerian  NG      ...  Test (ner -- wer)
# ...         ...  ..      ...                ...
# 27931  nigerian  NG      ...  Test (ner -- wer)
# 27932  nigerian  NG      ...  Test (ner -- wer)
# 27938  nigerian  NG      ...  Test (ner -- wer)
# 27941  nigerian  NG      ...  Test (ner -- wer)
# 27949  nigerian  NG      ...  Test (ner -- wer)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                     entities_group_prediction  \
# 0      [{'entity_group': 'PER', 'score': 0.768043, 'word': 'tan', 'start': 0, 'end': 3}]
# 2      [{'entity_group': 'DATE', 'score': 0.9996214, 'word': 'tuesday 28 april 1998', 'start': 0, 'end': 21}]
# 3      []
# 6      [{'entity_group': 'DATE', 'score': 0.9988054, 'word': 'this morning', 'start': 0, 'end': 12}, {'entity_group': 'LOC', 'score': 0.9966927, 'word': 'ibala', 'start': 24, 'end': 29}, {'entity_group': 'LOC', 'score': 0.98816526, 'word': 'ibala', 'start': 33, 'end': 38}, {'entity_group': 'PER', 'score': 0.92170006, 'word': 'utena', 'start': 50, 'end': 55}]
# 9      [{'entity_group': 'PER', 'score': 0.9973328, 'word': '', 'start': 4, 'end': 5}, {'entity_group': 'PER', 'score': 0.70736927, 'word': 'dotto', 'start': 4, 'end': 9}]
# ...                                                                                                                                                                     ...
# 27931  [{'entity_group': 'DATE', 'score': 0.9997705, 'word': '15march, 1988', 'start': 6, 'end': 19}, {'entity_group': 'PER', 'score': 0.98847884, 'word': 'unkama izichi', 'start': 23, 'end': 36}]
# 27932  [{'entity_group': 'PER', 'score': 0.89530236, 'word': 'chi', 'start': 10, 'end': 13}, {'entity_group': 'ORG', 'score': 0.95886433, 'word': 'fenichayo hospital', 'start': 29, 'end': 47}, {'entity_group': 'LOC', 'score': 0.824607, 'word': 'buguma', 'start': 51, 'end': 57}, {'entity_group': 'PER', 'score': 0.9933101, 'word': 'za', 'start': 68, 'end': 70}, {'entity_group': 'PER', 'score': 0.5758351, 'word': 'wna', 'start': 70, 'end': 73}]
# 27938  [{'entity_group': 'DATE', 'score': 0.9999844, 'word': '56yr', 'start': 19, 'end': 23}]
# 27941  []
# 27949  []
#
#         model_tag  \
# 0      pretrained
# 2      pretrained
# 3      pretrained
# 6      pretrained
# 9      pretrained
# ...           ...
# 27931  finetuned
# 27932  finetuned
# 27938  finetuned
# 27941  finetuned
# 27949  finetuned
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              entities_group  \
# 0      [{'entity_group': 'PER', 'score': 0.9998998641967773, 'word': 'Tinubu', 'start': 0, 'end': 6}]
# 2      [{'entity_group': 'DATE', 'score': 0.9999867677688599, 'word': 'Tuesday 28 April, 1998', 'start': 0, 'end': 22}, {'entity_group': 'PER', 'score': 0.9967962503433228, 'word': 'Daramola Achike', 'start': 44, 'end': 59}, {'entity_group': 'DATE', 'score': 0.999918520450592, 'word': '08 February, 2003', 'start': 60, 'end': 77}]
# 3      [{'entity_group': 'PER', 'score': 0.9999991655349731, 'word': 'A', 'start': 19, 'end': 20}, {'entity_group': 'PER', 'score': 0.9731560349464417, 'word': 'beni Chinememma', 'start': 20, 'end': 35}, {'entity_group': 'PER', 'score': 0.9991277456283569, 'word': 'Chinaecherem', 'start': 47, 'end': 59}]
# 6      [{'entity_group': 'DATE', 'score': 0.8826487064361572, 'word': 'This morning', 'start': 0, 'end': 12}, {'entity_group': 'PER', 'score': 0.9999626278877258, 'word': 'Chimereya', 'start': 13, 'end': 22}, {'entity_group': 'ORG', 'score': 0.99996018409729, 'word': 'Chinoye hospital', 'start': 31, 'end': 47}, {'entity_group': 'LOC', 'score': 0.9987977743148804, 'word': 'Ibadan', 'start': 51, 'end': 57}, {'entity_group': 'PER', 'score': 0.9999955892562866, 'word': 'Hussaina', 'start': 68, 'end': 76}]
# 9      [{'entity_group': 'PER', 'score': 0.9994386434555054, 'word': 'Nwanneka', 'start': 4, 'end': 12}, {'entity_group': 'PER', 'score': 0.9999184608459473, 'word': 'Na', 'start': 26, 'end': 28}, {'entity_group': 'PER', 'score': 0.576937735080719, 'word': 'gona', 'start': 28, 'end': 32}, {'entity_group': 'PER', 'score': 0.9997363686561584, 'word': 'ne', 'start': 74, 'end': 76}, {'entity_group': 'PER', 'score': 0.9977167844772339, 'word': 'ice Kujore', 'start': 76, 'end': 86}]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 27931  [{'entity_group': 'DATE', 'score': 0.9999293684959412, 'word': 'Tue 15 Mar, 1988', 'start': 0, 'end': 16}, {'entity_group': 'PER', 'score': 0.9999050498008728, 'word': 'Nkama Ezichi', 'start': 21, 'end': 33}, {'entity_group': 'ORG', 'score': 0.9191330075263977, 'word': 'Hospital Potiskum', 'start': 54, 'end': 71}]
# 27932  [{'entity_group': 'DATE', 'score': 0.9419776201248169, 'word': 'This morning', 'start': 0, 'end': 12}, {'entity_group': 'PER', 'score': 0.999982476234436, 'word': 'Chimdiomimi', 'start': 13, 'end': 24}, {'entity_group': 'ORG', 'score': 0.9999440908432007, 'word': 'Feyisayo hospital', 'start': 33, 'end': 50}, {'entity_group': 'LOC', 'score': 0.9994399547576904, 'word': 'Buguma', 'start': 54, 'end': 60}, {'entity_group': 'PER', 'score': 0.9999699592590332, 'word': 'Zauna', 'start': 71, 'end': 76}]
# 27938  [{'entity_group': 'PER', 'score': 0.9812123775482178, 'word': 'Ihechinyere Chinweizu', 'start': 0, 'end': 21}, {'entity_group': 'DATE', 'score': 0.9998412132263184, 'word': '56 yr', 'start': 22, 'end': 27}, {'entity_group': 'LOC', 'score': 0.9896509647369385, 'word': 'OR', 'start': 49, 'end': 51}, {'entity_group': 'ORG', 'score': 0.4551510512828827, 'word': 'S', 'start': 55, 'end': 56}, {'entity_group': 'DATE', 'score': 0.9999850392341614, 'word': '08-11-1989', 'start': 75, 'end': 85}]
# 27941  [{'entity_group': 'PER', 'score': 0.9942795634269714, 'word': 'Ifechiluru Kaetechukwu', 'start': 8, 'end': 30}]
# 27949  [{'entity_group': 'DATE', 'score': 0.9999850988388062, 'word': 'Wednesday night', 'start': 16, 'end': 31}, {'entity_group': 'ORG', 'score': 0.9998763799667358, 'word': 'Ibadan South-West Traditional Rulers Council', 'start': 85, 'end': 129}, {'entity_group': 'PER', 'score': 0.9999958276748657, 'word': 'Rashidi Ladoja', 'start': 153, 'end': 167}]
#
#                                                      ner_cat  \
# 0      tinubu
# 2      daramolaachike
# 3      abenichinememmachinaecherem
# 6      chimereyachinoyehospitalibadanhussaina
# 9      nwannekanagonaneicekujore
# ...                          ...
# 27931  nkamaezichihospitalpotiskum
# 27932  chimdiomimifeyisayohospitalbugumazauna
# 27938  ihechinyerechinweizuors
# 27941  ifechilurukaetechukwu
# 27949  ibadansouth-westtraditionalrulerscouncilrashidiladoja
#
#                  ner_cat_prediction            afri_ner_cat  \
# 0                                    tinubu
# 2                                    daramolaachike
# 3                                    chinememmachinaecherem
# 6      ibalaibalautena               chimereyahussaina
# 9                                    nwannekakujore
# ...   ..                                        ...
# 27931  unkamaizichi                  nkamaezichi
# 27932  chifenichayohospitalbugumaza  chimdiomimizauna
# 27938                                ihechinyerechinweizu
# 27941                                ifechilurukaetechukwu
# 27949                                rashidiladoja
#
#       afri_ner_cat_prediction afri_ner_count                    afri_ner
# 0                              1              [Tinubu]
# 2                              2              [Daramola, Achike]
# 3                              2              [Chinememma, Chinaecherem]
# 6                              2              [Chimereya, Hussaina]
# 9                              2              [Nwanneka, Kujore]
# ...   ..                      ..                             ...
# 27931                          2              [Nkama, Ezichi]
# 27932                          2              [Chimdiomimi, Zauna]
# 27938                          2              [Ihechinyere, Chinweizu]
# 27941                          2              [Ifechiluru, Kaetechukwu]
# 27949                          2              [Rashidi, Ladoja]
#
# [6575 rows x 24 columns]

# %%
split = "Test (afri-ner -- wer)"
all_model_entity["split"] = split

columns = [(split, "General"), (split, "Clinical"), (split, "Both")]
sort_by = (split, "General")

domain_df = domain_wer(all_model_entity[all_model_entity.loc[:, "afri_ner_count"] >= 1], 
                       metric="wer", 
                       columns=columns, 
                       sort_by=sort_by, 
                       references="reference",
                       predictions="prediction")
domain_df
# Out:
#                                                             Test (afri-ner -- wer)  \
#                                                                            General
# model_tag  name
# finetuned  openai/whisper-medium-general                     0.108
#            openai/whisper-medium-all                         0.117
#            facebook/wav2vec2-large-xlsr-53-english-general   0.212
#            facebook/wav2vec2-large-xlsr-53-english-all       0.256
# pretrained openai/whisper-large                              0.412
# finetuned  facebook/wav2vec2-large-xlsr-53-english-clinical  0.451
# pretrained openai/whisper-medium-en                          0.473
# finetuned  openai/whisper-medium-clinical                    0.476
# pretrained openai/whisper-medium                             0.488
#            Azure                                             0.509
#            openai/whisper-small                              0.542
#            AWS                                               0.556
#            openai/whisper-small-en                           0.588
#            facebook/wav2vec2-large-xlsr-53-english           0.617
#            AWS [Medical] (Primary Care)                      0.629
#            facebook/wav2vec2-xls-r-1b-english                0.638
#            GCP [Medical]                                     0.644
#            facebook/wav2vec2-large-960h-lv60-self            0.683
#            facebook/hubert-large-ls960-ft                    0.691
#            GCP                                               0.700
#            facebook/hubert-xlarge-ls960-ft                   0.701
#            microsoft/wavlm-libri-clean-100h-large            0.769
#            facebook/wav2vec2-large-960h                      0.802
#            microsoft/wavlm-libri-clean-100h-base             0.899
#            facebook/wav2vec2-large-robust-ft-swbd-300h       0.930
#
#
#                                                             Clinical   Both
# model_tag  name
# finetuned  openai/whisper-medium-general                     0.592    0.149
#            openai/whisper-medium-all                         0.280    0.131
#            facebook/wav2vec2-large-xlsr-53-english-general   0.576    0.243
#            facebook/wav2vec2-large-xlsr-53-english-all       0.395    0.268
# pretrained openai/whisper-large                              0.623    0.430
# finetuned  facebook/wav2vec2-large-xlsr-53-english-clinical  0.455    0.452
# pretrained openai/whisper-medium-en                          0.662    0.489
# finetuned  openai/whisper-medium-clinical                    0.421    0.471
# pretrained openai/whisper-medium                             0.628    0.500
#            Azure                                             0.704    0.526
#            openai/whisper-small                              0.665    0.552
#            AWS                                               0.882    0.584
#            openai/whisper-small-en                           0.662    0.595
#            facebook/wav2vec2-large-xlsr-53-english           0.848    0.637
#            AWS [Medical] (Primary Care)                      0.785    0.642
#            facebook/wav2vec2-xls-r-1b-english                0.895    0.660
#            GCP [Medical]                                     0.738    0.652
#            facebook/wav2vec2-large-960h-lv60-self            0.953    0.706
#            facebook/hubert-large-ls960-ft                    0.961    0.714
#            GCP                                               0.848    0.713
#            facebook/hubert-xlarge-ls960-ft                   1.021    0.728
#            microsoft/wavlm-libri-clean-100h-large            1.013    0.790
#            facebook/wav2vec2-large-960h                      1.071    0.825
#            microsoft/wavlm-libri-clean-100h-base             1.092    0.915
#            facebook/wav2vec2-large-robust-ft-swbd-300h       1.194    0.952

# %%
split = "Test (ner -- prediction cer)"
all_model_entity["split"] = split

columns = [(split, "General"), (split, "Clinical"), (split, "Both")]
sort_by = (split, "General")

domain_df = domain_wer(all_model_entity, 
                       metric="cer", 
                       columns=columns, 
                       sort_by=sort_by, 
                       references="ner_cat",
                       predictions="ner_cat_prediction")
domain_df
# Out:
#                                                             Test (ner -- prediction cer)  \
#                                                                                  General
# model_tag  name
# pretrained openai/whisper-large                              0.565
# finetuned  openai/whisper-medium-general                     0.576
#            openai/whisper-medium-all                         0.596
# pretrained openai/whisper-medium                             0.607
# finetuned  facebook/wav2vec2-large-xlsr-53-english-general   0.622
# pretrained openai/whisper-medium-en                          0.623
#            openai/whisper-small                              0.653
#            openai/whisper-small-en                           0.668
# finetuned  facebook/wav2vec2-large-xlsr-53-english-all       0.670
# pretrained Azure                                             0.674
#            AWS                                               0.735
#            facebook/wav2vec2-xls-r-1b-english                0.767
#            facebook/wav2vec2-large-xlsr-53-english           0.772
#            AWS [Medical] (Primary Care)                      0.801
#            facebook/hubert-xlarge-ls960-ft                   0.803
#            facebook/wav2vec2-large-960h-lv60-self            0.808
#            facebook/hubert-large-ls960-ft                    0.812
#            GCP                                               0.827
# finetuned  facebook/wav2vec2-large-xlsr-53-english-clinical  0.849
# pretrained facebook/wav2vec2-large-960h                      0.861
#            microsoft/wavlm-libri-clean-100h-large            0.864
# finetuned  openai/whisper-medium-clinical                    0.890
# pretrained facebook/wav2vec2-large-robust-ft-swbd-300h       0.892
#            microsoft/wavlm-libri-clean-100h-base             0.953
#            GCP [Medical]                                     0.973
#
#
#                                                             Clinical   Both
# model_tag  name
# pretrained openai/whisper-large                              0.841    0.587
# finetuned  openai/whisper-medium-general                     0.829    0.597
#            openai/whisper-medium-all                         0.836    0.615
# pretrained openai/whisper-medium                             0.854    0.627
# finetuned  facebook/wav2vec2-large-xlsr-53-english-general   0.848    0.640
# pretrained openai/whisper-medium-en                          0.884    0.644
#            openai/whisper-small                              0.860    0.670
#            openai/whisper-small-en                           0.877    0.685
# finetuned  facebook/wav2vec2-large-xlsr-53-english-all       0.882    0.687
# pretrained Azure                                             0.899    0.693
#            AWS                                               0.889    0.748
#            facebook/wav2vec2-xls-r-1b-english                0.908    0.778
#            facebook/wav2vec2-large-xlsr-53-english           0.926    0.784
#            AWS [Medical] (Primary Care)                      0.928    0.811
#            facebook/hubert-xlarge-ls960-ft                   0.930    0.813
#            facebook/wav2vec2-large-960h-lv60-self            0.929    0.818
#            facebook/hubert-large-ls960-ft                    0.944    0.823
#            GCP                                               0.930    0.835
# finetuned  facebook/wav2vec2-large-xlsr-53-english-clinical  0.902    0.853
# pretrained facebook/wav2vec2-large-960h                      0.922    0.866
#            microsoft/wavlm-libri-clean-100h-large            0.948    0.871
# finetuned  openai/whisper-medium-clinical                    0.920    0.893
# pretrained facebook/wav2vec2-large-robust-ft-swbd-300h       0.970    0.898
#            microsoft/wavlm-libri-clean-100h-base             0.977    0.955
#            GCP [Medical]                                     0.993    0.974

# %%
split = "Test (afri-ner -- predicted cer)"
all_model_entity["split"] = split

columns = [(split, "General"), (split, "Clinical"), (split, "Both")]
sort_by = (split, "General")

domain_df = domain_wer(all_model_entity[all_model_entity.loc[:, "afri_ner_cat"] != ""], 
                       metric="cer", 
                       columns=columns, 
                       sort_by=sort_by, 
                       references="afri_ner_cat",
                       predictions="afri_ner_cat_prediction")
domain_df
# Out:
#                                                             Test (afri-ner -- predicted cer)  \
#                                                                                      General
# model_tag  name
# finetuned  openai/whisper-medium-all                         0.700
#            openai/whisper-medium-general                     0.704
#            facebook/wav2vec2-large-xlsr-53-english-all       0.815
#            facebook/wav2vec2-large-xlsr-53-english-general   0.816
# pretrained openai/whisper-large                              0.855
#            openai/whisper-medium                             0.913
#            openai/whisper-medium-en                          0.927
#            openai/whisper-small-en                           0.934
# finetuned  openai/whisper-medium-clinical                    0.938
# pretrained openai/whisper-small                              0.940
#            Azure                                             0.946
# finetuned  facebook/wav2vec2-large-xlsr-53-english-clinical  0.947
# pretrained facebook/wav2vec2-xls-r-1b-english                0.951
#            facebook/wav2vec2-large-xlsr-53-english           0.965
#            AWS                                               0.970
#            facebook/wav2vec2-large-960h-lv60-self            0.978
#            facebook/hubert-large-ls960-ft                    0.981
#            microsoft/wavlm-libri-clean-100h-large            0.984
#            AWS [Medical] (Primary Care)                      0.985
#            facebook/hubert-xlarge-ls960-ft                   0.986
#            facebook/wav2vec2-large-960h                      0.986
#            GCP                                               0.991
#            facebook/wav2vec2-large-robust-ft-swbd-300h       0.993
#            microsoft/wavlm-libri-clean-100h-base             0.997
#            GCP [Medical]                                     1.000
#
#
#                                                             Clinical   Both
# model_tag  name
# finetuned  openai/whisper-medium-all                         0.866    0.717
#            openai/whisper-medium-general                     0.948    0.729
#            facebook/wav2vec2-large-xlsr-53-english-all       0.977    0.831
#            facebook/wav2vec2-large-xlsr-53-english-general   0.977    0.833
# pretrained openai/whisper-large                              0.948    0.865
#            openai/whisper-medium                             0.971    0.918
#            openai/whisper-medium-en                          0.971    0.931
#            openai/whisper-small-en                           0.980    0.939
# finetuned  openai/whisper-medium-clinical                    0.977    0.942
# pretrained openai/whisper-small                              1.000    0.946
#            Azure                                             0.971    0.949
# finetuned  facebook/wav2vec2-large-xlsr-53-english-clinical  1.000    0.953
# pretrained facebook/wav2vec2-xls-r-1b-english                1.000    0.956
#            facebook/wav2vec2-large-xlsr-53-english           1.000    0.968
#            AWS                                               0.990    0.972
#            facebook/wav2vec2-large-960h-lv60-self            0.977    0.978
#            facebook/hubert-large-ls960-ft                    0.977    0.981
#            microsoft/wavlm-libri-clean-100h-large            0.977    0.983
#            AWS [Medical] (Primary Care)                      0.990    0.986
#            facebook/hubert-xlarge-ls960-ft                   0.977    0.985
#            facebook/wav2vec2-large-960h                      0.971    0.985
#            GCP                                               1.000    0.992
#            facebook/wav2vec2-large-robust-ft-swbd-300h       1.000    0.993
#            microsoft/wavlm-libri-clean-100h-base             1.000    0.998
#            GCP [Medical]                                     1.000    1.000
