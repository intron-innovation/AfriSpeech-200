# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_metric
import sys
sys.path.append("..")
from src.utils.text_processing import clean_text

# %%
wer_metric = load_metric("wer")

# %%
dev_df = pd.read_csv("../data/intron-dev-public-3231-clean.csv")
print(dev_df.shape)
dev_df.head(3)
# Out:
# (3231, 14)
#       idx                          user_ids    accent age_group country  \
# 0  155349  659e36c14baaf7fa7bb197f951251f4b  setswana     26-40      BW
# 1   60812  1fd5f717cede9a867bf37d03c7d2166b   siswati     26-40      ZA
# 2  139668  f2d08d2e1c47a187bfa6869fadc1f755  setswana     26-40      ZA
#
#                                           transcript  nchars  \
# 0  We should be asking ourselves whether we want ...     110
# 1  Other sagittal planes parallel to this off cen...      88
# 2  Tuberculoma is an intracranial massoccurring s...     109
#
#                           audio_ids  \
# 0  86ad3ef21e469217f28a749c990c81fd
# 1  5409734bcc4a0f053e73f405d0f135da
# 2  b10dc4e959b6596d31866e5094ef500a
#
#                                          audio_paths  duration   origin  \
# 0  /AfriSpeech-100/dev/92d2b94e-3e31-40be-b479-50...  8.400998  african
# 1  /AfriSpeech-100/dev/127bdba1-8bc8-44a4-9c37-8e...  5.236984  african
# 2  /AfriSpeech-100/dev/de0b1ee6-46f1-4eb6-a747-47...  7.072993  african
#
#      domain split  gender
# 0   general   dev    Male
# 1  clinical   dev  Female
# 2  clinical   dev    Male

# %%
dev_df = dev_df[~dev_df.duplicated(subset="audio_paths")]
print(dev_df.shape)
# Out:
# (3227, 14)

# %%
dev_df["audio_paths"] = dev_df["audio_paths"].apply(lambda x: x.replace("/AfriSpeech-100/dev/", "/data/data/intron/"))
df = pd.read_csv("../results/intron-open-dev-whisper_medium-wer-0.3049-2872.csv")
df = pd.merge(df, dev_df, on="audio_paths")
df.shape
# Out:
# (2872, 21)

# %%
mapping_df = df[["idx", "audio_paths"]]
mapping_df.head(3)
# Out:
#       idx                                        audio_paths
# 0   72663  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...
# 1  153902  /data/data/intron/7ce31a48-f507-4344-bc49-96de...
# 2   82671  /data/data/intron/b8f6fbc1-426f-4a4b-99db-c38d...

# %%
models_df = pd.DataFrame()
models_df_clean = pd.DataFrame()

# %%
# Handy functions
def transform_raw_df(df_raw, columns=[], fmt="intron_whisper"):
    assert fmt != "" or fmt is not None
    
    df = df_raw.copy()
    
    if fmt == "intron_whisper":
        df = pd.merge(df, dev_df, on="audio_paths")
        df = pd.merge(df, mapping_df, on="idx")

        df = df[columns+["transcript", "hypothesis", "audio_paths_x", "accent_x"]]
        df.loc[:, "accent"] = df.loc[:, "accent_x"]
        df.loc[:, "audio_paths"] = df.loc[:, "audio_paths_x"]
        df.loc[:, "reference"] = df.loc[:, "transcript"]
        df.loc[:, "prediction"] = df.loc[:, "hypothesis"]
        df = df.drop(columns=["accent_x", "audio_paths_x", "hypothesis", "transcript"])
    
    elif fmt == "african_nlp":
        df = pd.merge(df, dev_df, on="audio_paths")
        df = pd.merge(df, mapping_df, on="idx")

        df = df[columns+["accent", "user_ids", "transcript", 1]]
        df.loc[:, "reference"] = df.loc[:, "transcript"]
        df.loc[:, "prediction"] = df.loc[:, 1]
        df = df.drop(columns=[1, "transcript"])

    elif fmt == "aws":
        df = pd.merge(df[["idx", "transcript", "predictions"]], dev_df, on="idx")
        df = pd.merge(df, mapping_df, on="idx")

        df = df[columns+["accent", "user_ids", "transcript_x", "predictions"]]
        df.loc[:, "reference"] = df.loc[:, "transcript_x"]
        df.loc[:, "prediction"] = df.loc[:, "predictions"]
        df = df.drop(columns=["transcript_x", "predictions"])

    elif fmt == "azure":
        df = pd.merge(df[["idx", "transcript", "predictions_raw"]], dev_df, on="idx")
        df = pd.merge(df, mapping_df, on="idx")

        df = df[columns+["accent", "user_ids", "transcript_x", "predictions_raw"]]
        df.loc[:, "reference"] = df.loc[:, "transcript_x"]
        df.loc[:, "prediction"] = df.loc[:, "predictions_raw"]
        df = df.drop(columns=["transcript_x", "predictions_raw"])
    
    elif fmt == "wav2vec2":
        df.loc[:, "audio_paths"] = df["audio_path"]
        df = pd.merge(df[["audio_paths", "text", "predictions_raw"]], dev_df, on="audio_paths")
        df = pd.merge(df, mapping_df, on="idx")

        df = df[columns+["accent", "user_ids", "text", "predictions_raw"]]
        df.loc[:, "reference"] = df.loc[:, "text"]
        df.loc[:, "prediction"] = df.loc[:, "predictions_raw"]
        df = df.drop(columns=["text", "predictions_raw"])
    
    elif fmt in df.columns:
        df = pd.merge(df[["idx", "transcript", fmt]], dev_df, on="idx")
        df = pd.merge(df, mapping_df, on="idx")

        df = df[columns+["accent", "user_ids", "transcript_x", fmt]]
        df.loc[:, "reference"] = df.loc[:, "transcript_x"]
        df.loc[:, "prediction"] = df.loc[:, fmt]
        df = df.drop(columns=["transcript_x", fmt])
  
    else:
        raise NotImplementedError()
    
    print(df.shape)
    df["wer"] = df.apply(lambda x: wer_metric.compute(predictions=[x.prediction], references=[x.reference]), axis=1) 
    return df
    


def clean_and_compute_wer(df):
    df_clean = df.copy()
    
    print(df_clean[df_clean["prediction"].isnull()].shape)
    
    df_clean["prediction"] = df_clean["prediction"].fillna("")
    print(df_clean[df_clean["prediction"].isnull()].shape)
    
    df_clean["reference"] = df_clean["reference"].apply(lambda x: clean_text(x))
    df_clean["prediction"] = df_clean["prediction"].apply(lambda x: clean_text(x))
    
    df_clean["wer"] = df_clean.apply(lambda x: wer_metric.compute(predictions=[x.prediction], 
                                                                  references=[x.reference]), axis=1)
    return df_clean
    
    
def write_to_folder(model_id_or_path, predictions_df, output_dir="../results/", split="dev"):
    wer = predictions_df["wer"].mean()
    output_path = f"{output_dir}/intron-open-{split}-{model_id_or_path}-wer-{round(wer, 4)}-{len(predictions_df)}.csv"
    predictions_df.to_csv(output_path, index=False)

# %%
# make output dir
import os
os.makedirs("../results/raw", exist_ok=True)
os.makedirs("../results/normalized", exist_ok=True)

# %% [markdown]
# # Compute WER

# %% [markdown]
# ## OpenAI

# %%
whspr = pd.read_csv("../results/whisper_wer_asr_dev.csv")
print(whspr.shape)
whspr.head(3)
# Out:
# (3232, 10)
#    Unnamed: 0     idx                          user_ids  \
# 0           0   72663  f559cb4f16bc465ea44b56a8d3b5513e
# 1           1  153902  2be9bc423e70a24c703f8336e60af3f3
# 2           2   82671  a3c2c182b6b53089ef4bc3eccff103bf
#
#                                           transcript  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
# 2  For Nigeria to achieve similar noble goals, th...
#
#                                       whisper_medium  \
# 0   Ensure the correct placement of the feeding t...
# 1   Regardless of how amyokites stimulated, howev...
# 2   For Nigeria to achieve similar noble goals, t...
#
#                                        whisper_large       wer  \
# 0   Ensure the correct placement of the feeding t...  0.451613
# 1   Regardless of how a myocardial stimulation, h...  0.444444
# 2   For Nigeria to achieve similar noble goals, t...  0.222222
#
#                                   cleanup_references  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated however...
# 2  for nigeria to achieve similar noble goals  th...
#
#                                      cleanup_whisper  wer_cleanup
# 0  ensure the correct placement of the feeding tu...     0.290323
# 1  regardless of how amyokites stimulated  howeve...     0.250000
# 2  for nigeria to achieve similar noble goals  th...     0.027778

# %%
columns = ["idx", "domain", "gender", "duration", "age_group"]

# %% [markdown]
# ### Whisper-Large

# %%
whspr_large = transform_raw_df(whspr, columns=columns, fmt="whisper_large")
whspr_large_clean = clean_and_compute_wer(whspr_large)
# Out:
# (2872, 9)
# (3, 10)
# (0, 10)

# %%
whspr_large.head(2)
# Out:
#       idx    domain  gender   duration age_group   accent  \
# 0   72663  clinical  Female  16.421995     19-25  swahili
# 1  153902  clinical  Female  11.393991     19-25  swahili
#
#                            user_ids  \
# 0  f559cb4f16bc465ea44b56a8d3b5513e
# 1  2be9bc423e70a24c703f8336e60af3f3
#
#                                            reference  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                           prediction       wer
# 0   Ensure the correct placement of the feeding t...  0.290323
# 1   Regardless of how a myocardial stimulation, h...  0.500000

# %%
whspr_large_clean.head(2)
# Out:
#       idx    domain  gender   duration age_group   accent  \
# 0   72663  clinical  Female  16.421995     19-25  swahili
# 1  153902  clinical  Female  11.393991     19-25  swahili
#
#                            user_ids  \
# 0  f559cb4f16bc465ea44b56a8d3b5513e
# 1  2be9bc423e70a24c703f8336e60af3f3
#
#                                            reference  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                           prediction       wer
# 0  ensure the correct placement of the feeding tu...  0.290323
# 1  regardless of how a myocardial stimulation, ho...  0.500000

# %%
# WER
print(whspr_large["wer"].mean())
print(whspr_large_clean["wer"].mean())
# Out:
# 0.5039740585544689
# 0.4108835197703194

# %%
model_id_or_path = "openai_whisper_large"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_large, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_large_clean,
                output_dir="../results/normalized")

# %%
whspr_large["name"] = "openai_whisper_large"
whspr_large_clean["name"] = "openai_whisper_large"

models_df = pd.concat([models_df, whspr_large])
models_df_clean = pd.concat([models_df_clean, whspr_large_clean])

# %% [markdown]
# ### Whisper-Medium

# %%
whspr_medium_raw = pd.read_csv("../results/intron-open-dev-whisper_medium-wer-0.3049-2872.csv")
print(whspr_medium_raw.shape)
whspr_medium_raw.head(2)
# Out:
# (2872, 8)
#                                           hypothesis  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardless of how amyokites stimulated, howeve...
#
#                                            reference  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                          audio_paths   accent  \
# 0  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...  swahili
# 1  /data/data/intron/7ce31a48-f507-4344-bc49-96de...  swahili
#
#                                           pred_clean  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardless of how amyokites stimulated, howeve...
#
#                                            ref_clean  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                     hypothesis_clean  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardless of how amyokites stimulated however...
#
#                                      reference_clean
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated however...

# %%
whspr_medium = transform_raw_df(whspr_medium_raw, columns=columns, fmt="intron_whisper")
whspr_medium_clean = clean_and_compute_wer(whspr_medium)
# Out:
# (2872, 9)
# (0, 10)
# (0, 10)

# %%
# WER
print(whspr_medium["wer"].mean())
print(whspr_medium_clean["wer"].mean())
# Out:
# 0.4643886864352219
# 0.34914988813403375

# %%
model_id_or_path = "openai_whisper_medium"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_medium, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_medium_clean,
                output_dir="../results/normalized")

# %%
whspr_medium["name"] = "openai_whisper_medium"
whspr_medium_clean["name"] = "openai_whisper_medium"

models_df = pd.concat([models_df, whspr_medium])
models_df_clean = pd.concat([models_df_clean, whspr_medium_clean])

# %%
whspr_medium_en_raw = pd.read_csv("../results/intron-open-dev-whisper_medium.en-wer-0.3219-2872.csv")
print(whspr_medium_en_raw.shape)
whspr_medium_en = transform_raw_df(whspr_medium_en_raw, columns=columns, fmt="intron_whisper")
whspr_medium_en_clean = clean_and_compute_wer(whspr_medium_en)
# Out:
# (2872, 8)
# (2872, 9)
# (0, 10)
# (0, 10)

# %%
print(whspr_medium_en["wer"].mean())
print(whspr_medium_en_clean["wer"].mean())
# Out:
# 0.46137424273526506
# 0.3678484564644302

# %%
model_id_or_path = "openai_whisper_medium_en"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_medium_en, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_medium_en_clean,
                output_dir="../results/normalized")

# %%
whspr_medium_en["name"] = "openai_whisper_medium_en"
whspr_medium_en_clean["name"] = "openai_whisper_medium_en"

models_df = pd.concat([models_df, whspr_medium_en])
models_df_clean = pd.concat([models_df_clean, whspr_medium_en_clean])

# %% [markdown]
# ### Whisper-Small

# %%
whspr_small_raw = pd.read_csv("../results/intron-open-dev-whisper_small-wer-0.3743-2872.csv")
print(whspr_small_raw.shape)
whspr_small_raw.head(2)
# Out:
# (2872, 8)
#                                           hypothesis  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardless of how a moeocatase stimulated, how...
#
#                                            reference  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                          audio_paths   accent  \
# 0  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...  swahili
# 1  /data/data/intron/7ce31a48-f507-4344-bc49-96de...  swahili
#
#                                           pred_clean  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardless of how a moeocatase stimulated, how...
#
#                                            ref_clean  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                     hypothesis_clean  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardless of how a moeocatase stimulated howe...
#
#                                      reference_clean
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated however...

# %%
whspr_small = transform_raw_df(whspr_small_raw, columns=columns, fmt="intron_whisper")
whspr_small_clean = clean_and_compute_wer(whspr_small)
# Out:
# (2872, 9)
# (0, 10)
# (0, 10)

# %%
print(whspr_small["wer"].mean())
print(whspr_small_clean["wer"].mean())
# Out:
# 0.5337821026197487
# 0.43133830977562343

# %%
model_id_or_path = "openai_whisper_small"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_small, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_small_clean,
                output_dir="../results/normalized")

# %%
whspr_small["name"] = "openai_whisper_small"
whspr_small_clean["name"] = "openai_whisper_small"

models_df = pd.concat([models_df, whspr_small])
models_df_clean = pd.concat([models_df_clean, whspr_small_clean])

# %%
whspr_small_en_raw = pd.read_csv("../results/intron-open-dev-whisper_small.en-wer-0.383-2872.csv")
print(whspr_small_en_raw.shape)
whspr_small_en = transform_raw_df(whspr_small_en_raw, columns=columns, fmt="intron_whisper")
whspr_small_en_clean = clean_and_compute_wer(whspr_small_en)
# Out:
# (2872, 8)
# (2872, 9)
# (0, 10)
# (0, 10)

# %%
print(whspr_small_en["wer"].mean())
print(whspr_small_en_clean["wer"].mean())
# Out:
# 0.519713022377241
# 0.43402733892570033

# %%
model_id_or_path = "openai_whisper_small_en"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_small_en, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=whspr_small_en_clean,
                output_dir="../results/normalized")

# %%
whspr_small_en["name"] = "openai_whisper_small_en"
whspr_small_en_clean["name"] = "openai_whisper_small_en"

models_df = pd.concat([models_df, whspr_small_en])
models_df_clean = pd.concat([models_df_clean, whspr_small_en_clean])

# %%
models_df.shape, models_df_clean.shape
# Out:
# ((14360, 12), (14360, 12))

# %% [markdown]
# ## Nvidia

# %% [markdown]
# ### Nemo-conformer-ctc-large

# %%
nemo_ctc_raw = pd.read_csv("../results/african-nlp-nemo-ctc-predictons", header=None, delimiter="	")
nemo_ctc_raw["audio_paths"] = nemo_ctc_raw[0].apply(lambda x: x.replace("/scratch/pbsjobs/axy327/dev/", "/data/data/intron/"))
print(nemo_ctc_raw.shape)
nemo_ctc_raw.head(2)
# Out:
# (3227, 3)
#                                                    0  \
# 0  /scratch/pbsjobs/axy327/dev/a25d5981-d814-4eef...
# 1  /scratch/pbsjobs/axy327/dev/35a17e2f-5b12-4886...
#
#                                                    1  \
# 0                        construction and sea trials
# 1  unstable bos fracture of unspecified thoracic ...
#
#                                          audio_paths
# 0  /data/data/intron/a25d5981-d814-4eef-8637-cc35...
# 1  /data/data/intron/35a17e2f-5b12-4886-ad2c-c1aa...

# %%
nemo_ctc = transform_raw_df(nemo_ctc_raw, columns=columns, fmt="african_nlp")
nemo_ctc_clean = clean_and_compute_wer(nemo_ctc)
# Out:
# (2872, 9)
# (2, 10)
# (0, 10)

# %%
print(nemo_ctc["wer"].mean())
print(nemo_ctc_clean["wer"].mean())
# Out:
# 0.6767011051916588
# 0.5503160383940416

# %%
model_id_or_path = "nvidia_nemo_conformer_ctc_large"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=nemo_ctc, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=nemo_ctc_clean,
                output_dir="../results/normalized")

# %%
nemo_ctc["name"] = "nvidia_nemo_conformer_ctc_large"
nemo_ctc_clean["name"] = "nvidia_nemo_conformer_ctc_large"

models_df = pd.concat([models_df, nemo_ctc])
models_df_clean = pd.concat([models_df_clean, nemo_ctc_clean])

# %% [markdown]
# ### Nemo-conformer-transducer-large

# %%
nemo_transducer_raw = pd.read_csv("../results/african-nlp-nemo-transducer-predictons", header=None, delimiter="	")
nemo_transducer_raw["audio_paths"] = nemo_transducer_raw[0].apply(lambda x: x.replace("/scratch/pbsjobs/axy327/dev/", "/data/data/intron/"))
print(nemo_transducer_raw.shape)
nemo_transducer_raw.head(2)
# Out:
# (3227, 3)
#                                                    0  \
# 0  /scratch/pbsjobs/axy327/dev/a25d5981-d814-4eef...
# 1  /scratch/pbsjobs/axy327/dev/35a17e2f-5b12-4886...
#
#                                                    1  \
# 0                        construction and sea trials
# 1  unstable boss fracture of unspecified thoracic...
#
#                                          audio_paths
# 0  /data/data/intron/a25d5981-d814-4eef-8637-cc35...
# 1  /data/data/intron/35a17e2f-5b12-4886-ad2c-c1aa...

# %%
nemo_transducer = transform_raw_df(nemo_transducer_raw, columns=columns, fmt="african_nlp")
nemo_transducer_clean = clean_and_compute_wer(nemo_transducer)
# Out:
# (2872, 9)
# (6, 10)
# (0, 10)

# %%
print(nemo_transducer["wer"].mean())
print(nemo_transducer_clean["wer"].mean())
# Out:
# 0.6637992751483184
# 0.5245269422772046

# %%
model_id_or_path = "nvidia_nemo_conformer_transducer_large"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=nemo_transducer, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=nemo_transducer_clean,
                output_dir="../results/normalized")

# %%
nemo_transducer["name"] = "nvidia_nemo_conformer_transducer_large"
nemo_transducer_clean["name"] = "nvidia_nemo_conformer_transducer_large"

models_df = pd.concat([models_df, nemo_transducer])
models_df_clean = pd.concat([models_df_clean, nemo_transducer_clean])

# %% [markdown]
# ## Speech Brain

# %%
speech_brain_raw = pd.read_csv("../results/african-nlp-speechbrain-predictons", header=None, delimiter="	")
speech_brain_raw["audio_paths"] = nemo_transducer_raw[0].apply(lambda x: x.replace("/scratch/pbsjobs/axy327/dev/", "/data/data/intron/"))
print(speech_brain_raw.shape)
speech_brain_raw.head(2)
# Out:
# (3227, 3)
#                                                    0  \
# 0  /scratch/pbsjobs/axy327/dev/a25d5981-d814-4eef...
# 1  /scratch/pbsjobs/axy327/dev/35a17e2f-5b12-4886...
#
#                                                    1  \
# 0                          CONSTRUCTION AND C TRIALS
# 1  STUBBLE BOSS RUPTURE OF OSPREY'S WIFE'S THORAC...
#
#                                          audio_paths
# 0  /data/data/intron/a25d5981-d814-4eef-8637-cc35...
# 1  /data/data/intron/35a17e2f-5b12-4886-ad2c-c1aa...

# %%
speech_brain = transform_raw_df(speech_brain_raw, columns=columns, fmt="african_nlp")
speech_brain_clean = clean_and_compute_wer(speech_brain)
# Out:
# (2872, 9)
# (1, 10)
# (0, 10)

# %%
print(speech_brain["wer"].mean())
print(speech_brain_clean["wer"].mean())
# Out:
# 1.3610988905098031
# 0.976453580724285

# %%
model_id_or_path="speechbrain_crdnn_rnnlm_librispeech"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=speech_brain, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=speech_brain_clean,
                output_dir="../results/normalized")

# %%
speech_brain["name"] = "speechbrain_crdnn_rnnlm_librispeech"
speech_brain_clean["name"] = "speechbrain_crdnn_rnnlm_librispeech"

models_df = pd.concat([models_df, speech_brain])
models_df_clean = pd.concat([models_df_clean, speech_brain_clean])

# %% [markdown]
# ## AWS

# %% [markdown]
# ### Medical API (Primary Care)

# %%
aws_medical_raw = pd.read_csv("../results/intron-open-dev-aws-transcribe-medical-wer-0.5544-3232.csv")
print(aws_medical_raw.shape)
aws_medical_raw.head(2)
# Out:
# (3232, 15)
#       idx                          user_ids   accent age_group country  \
# 0   72663  f559cb4f16bc465ea44b56a8d3b5513e  swahili     19-25      KE
# 1  153902  2be9bc423e70a24c703f8336e60af3f3  swahili     19-25      KE
#
#                                           transcript  nchars  \
# 0  Ensure the correct placement of the feeding tu...     206
# 1  Regardlessof how amyocyteis stimulated,however...     143
#
#                           audio_ids  \
# 0  29af500daee748498b3329352fbc170a
# 1  b87324a3c5ca065494f385e4f49e4b23
#
#                                          audio_paths   duration   origin  \
# 0  /AfriSpeech-100/dev/e809b58c-4f05-4754-b98c-fb...  16.421995  african
# 1  /AfriSpeech-100/dev/7ce31a48-f507-4344-bc49-96...  11.393991  african
#
#      domain split                                        predictions       wer
# 0  clinical   dev  ensure the correct placement of the feeding tu...  0.451613
# 1  clinical   dev  regardless of how a market is stimulated, howe...  0.555556

# %%
aws_medical = transform_raw_df(aws_medical_raw, columns=columns, fmt="aws")
aws_medical_clean = clean_and_compute_wer(aws_medical)
# Out:
# (2872, 9)
# (1, 10)
# (0, 10)

# %%
print(aws_medical["wer"].mean())
print(aws_medical_clean["wer"].mean())
# Out:
# 0.6347359704426636
# 0.5358062344446374

# %%
model_id_or_path="amazon_aws_transcribe_medical_api_primary_care"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=aws_medical, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=aws_medical_clean,
                output_dir="../results/normalized")

# %%
aws_medical["name"] = "amazon_aws_transcribe_medical_api_primary_care"
aws_medical_clean["name"] = "amazon_aws_transcribe_medical_api_primary_care"

models_df = pd.concat([models_df, aws_medical])
models_df_clean = pd.concat([models_df_clean, aws_medical_clean])

# %% [markdown]
# ### Non-medical API

# %%
aws_raw = pd.read_csv("../results/intron-open-dev-aws-transcribe-wer-0.5212-3232.csv")
print(aws_raw.shape)
aws_raw.head(2)
# Out:
# (3232, 15)
#       idx                          user_ids   accent age_group country  \
# 0   72663  f559cb4f16bc465ea44b56a8d3b5513e  swahili     19-25      KE
# 1  153902  2be9bc423e70a24c703f8336e60af3f3  swahili     19-25      KE
#
#                                           transcript  nchars  \
# 0  Ensure the correct placement of the feeding tu...     206
# 1  Regardlessof how amyocyteis stimulated,however...     143
#
#                           audio_ids  \
# 0  29af500daee748498b3329352fbc170a
# 1  b87324a3c5ca065494f385e4f49e4b23
#
#                                          audio_paths   duration   origin  \
# 0  /AfriSpeech-100/dev/e809b58c-4f05-4754-b98c-fb...  16.421995  african
# 1  /AfriSpeech-100/dev/7ce31a48-f507-4344-bc49-96...  11.393991  african
#
#      domain split                                        predictions       wer
# 0  clinical   dev  ensure the correct placement of the feeding tu...  0.516129
# 1  clinical   dev  regardless of how a market is stimulated, howe...  0.555556

# %%
aws = transform_raw_df(aws_raw, columns=columns, fmt="aws")
aws_clean = clean_and_compute_wer(aws)
# Out:
# (2872, 9)
# (7, 10)
# (0, 10)

# %%
print(aws["wer"].mean())
print(aws_clean["wer"].mean())
# Out:
# 0.5992453253269371
# 0.49882406211336133

# %%
model_id_or_path="amazon_aws_transcribe_api"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=aws, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=aws_clean,
                output_dir="../results/normalized")

# %%
aws["name"] = "amazon_aws_transcribe_api"
aws_clean["name"] = "amazon_aws_transcribe_api"

models_df = pd.concat([models_df, aws])
models_df_clean = pd.concat([models_df_clean, aws_clean])

# %% [markdown]
# ## Google

# %% [markdown]
# ### GCP Speech Non-medical API

# %%
gcp_raw = pd.read_csv("../results/gcp_wer_asr_dev.csv")
print(gcp_raw.shape)
gcp_raw.head(2)
# Out:
# (3232, 9)
#    Unnamed: 0     idx                          user_ids  \
# 0           0   72663  f559cb4f16bc465ea44b56a8d3b5513e
# 1           1  153902  2be9bc423e70a24c703f8336e60af3f3
#
#                                           transcript  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                                  gcp       wer  \
# 0  cancel the correct placement of the feeding tu...  0.580645
# 1  regardless of how American cheese stimulated a...  0.722222
#
#                                   cleanup_references  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated however...
#
#                                          cleanup_gcp  wer_cleanup
# 0  cancel the correct placement of the feeding tu...     0.580645
# 1  regardless of how american cheese stimulated a...     0.550000

# %%
gcp = transform_raw_df(gcp_raw, columns=columns, fmt="gcp")
gcp_clean = clean_and_compute_wer(gcp)
# Out:
# (2872, 9)
# (85, 10)
# (0, 10)

# %%
print(gcp["wer"].mean())
print(gcp_clean["wer"].mean())
# Out:
# 0.6566726487334155
# 0.5993110736614581

# %%
model_id_or_path="google_gcp_speech_api"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=gcp, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=gcp_clean,
                output_dir="../results/normalized")

# %%
gcp["name"] = "google_gcp_speech_api"
gcp_clean["name"] = "google_gcp_speech_api"

models_df = pd.concat([models_df, gcp])
models_df_clean = pd.concat([models_df_clean, gcp_clean])

# %% [markdown]
# ## Microsoft

# %% [markdown]
# ### Azure

# %%
azure_raw = pd.read_csv("../results/intron-open-dev-azure-transcribe-wer-0.5038-2883.csv")
print(azure_raw.shape)
azure_raw.head(2)
# Out:
# (2883, 16)
#       idx                          user_ids   accent age_group country  \
# 0   72663  f559cb4f16bc465ea44b56a8d3b5513e  swahili     19-25      KE
# 1  153902  2be9bc423e70a24c703f8336e60af3f3  swahili     19-25      KE
#
#                                           transcript  nchars  \
# 0  Ensure the correct placement of the feeding tu...     206
# 1  Regardlessof how amyocyteis stimulated,however...     143
#
#                           audio_ids  \
# 0  29af500daee748498b3329352fbc170a
# 1  b87324a3c5ca065494f385e4f49e4b23
#
#                                          audio_paths   duration   origin  \
# 0  /AfriSpeech-100/dev/e809b58c-4f05-4754-b98c-fb...  16.421995  african
# 1  /AfriSpeech-100/dev/7ce31a48-f507-4344-bc49-96...  11.393991  african
#
#      domain split                                    predictions_raw  \
# 0  clinical   dev  Ensure the correct placement of the feeding tu...
# 1  clinical   dev  Regardless of how America is stimulated, howev...
#
#                                          predictions       wer
# 0  ensure the correct placement of the feeding tu...  0.290323
# 1  regardless of how america is stimulated, howev...  0.500000

# %%
azure = transform_raw_df(azure_raw, columns=columns, fmt="azure")
azure_clean = clean_and_compute_wer(azure)
# Out:
# (2872, 9)
# (501, 10)
# (0, 10)

# %%
print(azure["wer"].mean())
print(azure_clean["wer"].mean())
# Out:
# 0.5948180547456207
# 0.5169678167305342

# %%
model_id_or_path="microsoft_azure_speech_api"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=azure, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=azure_clean,
                output_dir="../results/normalized")

# %%
azure["name"] = "microsoft_azure_speech_api"
azure_clean["name"] = "microsoft_azure_speech_api"

models_df = pd.concat([models_df, azure])
models_df_clean = pd.concat([models_df_clean, azure_clean])

# %%
models_df.shape, models_df_clean.shape
# Out:
# ((34464, 12), (34464, 12))

# %% [markdown]
# ### WavLm-libri-clean-100h-large

# %%
wavlm_libri_clean_100h_large_raw = pd.read_csv("../results/intron-open-dev-ful-patrickvonplaten-wavlm-libri-clean-100h-large-wer-0.6938-3232.csv")
print(wavlm_libri_clean_100h_large_raw.shape)
wavlm_libri_clean_100h_large_raw.head(2)
# Out:
# (3232, 7)
#                                           audio_path  \
# 0  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...
# 1  /data/data/intron/7ce31a48-f507-4344-bc49-96de...
#
#                                                 text  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                            reference  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                          predictions  \
# 0  enshured the corect placement of the feiding t...
# 1  regadless of how amocety stimulated however th...
#
#                                      predictions_raw       wer   accent
# 0  enshured the corect placement of the feiding t...  0.806452  swahili
# 1  regadless of how amocety stimulated however th...  0.666667  swahili

# %%
wavlm_libri_clean_100h_large = transform_raw_df(wavlm_libri_clean_100h_large_raw, columns=columns, fmt="wav2vec2")
wavlm_libri_clean_100h_large_clean = clean_and_compute_wer(wavlm_libri_clean_100h_large)
# Out:
# (2877, 9)
# (1, 10)
# (0, 10)

# %%
print(wavlm_libri_clean_100h_large["wer"].mean())
print(wavlm_libri_clean_100h_large_clean["wer"].mean())
# Out:
# 0.8328127595669096
# 0.7692137602897249

# %%
model_id_or_path="microsoft_wavlm_libri_clean_100h_large"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wavlm_libri_clean_100h_large, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wavlm_libri_clean_100h_large_clean,
                output_dir="../results/normalized")

# %%
wavlm_libri_clean_100h_large["name"] = "microsoft_wavlm_libri_clean_100h_large"
wavlm_libri_clean_100h_large_clean["name"] = "microsoft_wavlm_libri_clean_100h_large"

models_df = pd.concat([models_df, wavlm_libri_clean_100h_large])
models_df_clean = pd.concat([models_df_clean, wavlm_libri_clean_100h_large_clean])

# %% [markdown]
# ### WavLm-libri-clean-100h-base-plus

# %%
wavlm_libri_clean_100h_base_raw = pd.read_csv("../results/wavLM_wer_asr_dev.csv")
print(wavlm_libri_clean_100h_base_raw.shape)
wavlm_libri_clean_100h_base_raw.head(2)
# Out:
# (3232, 9)
#    Unnamed: 0     idx                          user_ids  \
# 0           0   72663  f559cb4f16bc465ea44b56a8d3b5513e
# 1           1  153902  2be9bc423e70a24c703f8336e60af3f3
#
#                                           transcript  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                                wavLM       wer  \
# 0  ensu the correct placement of the fiding tube ...  0.903226
# 1  regardless of how amuketisstimulated however t...  0.722222
#
#                                   cleanup_references  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated however...
#
#                                        cleanup_wavLM  wer_cleanup
# 0  ensu the correct placement of the fiding tube ...      0.83871
# 1  regardless of how amuketisstimulated however t...      0.60000

# %%
wavlm_libri_clean_100h_base = transform_raw_df(wavlm_libri_clean_100h_base_raw, columns=columns, fmt="wavLM")
wavlm_libri_clean_100h_base_clean = clean_and_compute_wer(wavlm_libri_clean_100h_base)
# Out:
# (2872, 9)
# (2, 10)
# (0, 10)

# %%
print(wavlm_libri_clean_100h_base["wer"].mean())
print(wavlm_libri_clean_100h_base_clean["wer"].mean())
# Out:
# 0.9022293171522732
# 0.8549641714400352

# %%
model_id_or_path="microsoft_wavlm_libri_clean_100h_base"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wavlm_libri_clean_100h_base, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wavlm_libri_clean_100h_base_clean,
                output_dir="../results/normalized")

# %%
wavlm_libri_clean_100h_base["name"] = "microsoft_wavlm_libri_clean_100h_base"
wavlm_libri_clean_100h_base_clean["name"] = "microsoft_wavlm_libri_clean_100h_base"

models_df = pd.concat([models_df, wavlm_libri_clean_100h_base])
models_df_clean = pd.concat([models_df_clean, wavlm_libri_clean_100h_base_clean])

# %% [markdown]
# ## Facebook

# %% [markdown]
# ### Wav2vec2-large-xlsr-53-english

# %%
wav2vec2_large_xlsr_53_english_raw = pd.read_csv("../results/intron-open-dev-ful-jonatasgrosman-wav2vec2-large-xlsr-53-english-wer-0.5606-3232.csv")
print(wav2vec2_large_xlsr_53_english_raw.shape)
wav2vec2_large_xlsr_53_english_raw.head(2)
# Out:
# (3232, 7)
#                                           audio_path  \
# 0  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...
# 1  /data/data/intron/7ce31a48-f507-4344-bc49-96de...
#
#                                                 text  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                            reference  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                          predictions  \
# 0  ensure the correct replacement of the feeding ...
# 1  regardless of how amerchetis stimulated howeve...
#
#                                      predictions_raw       wer   accent
# 0  ensure the correct replacement of the feeding ...  0.709677  swahili
# 1  regardless of how amerchetis stimulated howeve...  0.611111  swahili

# %%
wav2vec2_large_xlsr_53_english = transform_raw_df(wav2vec2_large_xlsr_53_english_raw, columns=columns, fmt="wav2vec2")
wav2vec2_large_xlsr_53_english_clean = clean_and_compute_wer(wav2vec2_large_xlsr_53_english)
# Out:
# (2877, 9)
# (1, 10)
# (0, 10)

# %%
print(wav2vec2_large_xlsr_53_english["wer"].mean())
print(wav2vec2_large_xlsr_53_english_clean["wer"].mean())
# Out:
# 0.7152722570406036
# 0.6398663107153179

# %%
model_id_or_path="facebook_wav2vec2_large_xlsr_53_english"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_large_xlsr_53_english, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_large_xlsr_53_english_clean,
                output_dir="../results/normalized")

# %%
wav2vec2_large_xlsr_53_english["name"] = "facebook_wav2vec2_large_xlsr_53_english"
wav2vec2_large_xlsr_53_english_clean["name"] = "facebook_wav2vec2_large_xlsr_53_english"

models_df = pd.concat([models_df, wav2vec2_large_xlsr_53_english])
models_df_clean = pd.concat([models_df_clean, wav2vec2_large_xlsr_53_english_clean])

# %% [markdown]
# ### Wav2vec2-xls-r-1b-english

# %%
wav2vec2_xls_r_1b_english_raw = pd.read_csv("../results/intron-open-dev-ful-jonatasgrosman-wav2vec2-xls-r-1b-english-wer-0.5761-3232.csv")
print(wav2vec2_xls_r_1b_english_raw.shape)
wav2vec2_xls_r_1b_english_raw.head(2)
# Out:
# (3232, 7)
#                                           audio_path  \
# 0  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...
# 1  /data/data/intron/7ce31a48-f507-4344-bc49-96de...
#
#                                                 text  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                            reference  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                          predictions  \
# 0  ensure the correct replacement of the feeding ...
# 1  regardless of how amceteis stimulated however ...
#
#                                      predictions_raw       wer   accent
# 0  ensure the correct replacement of the feeding ...  0.709677  swahili
# 1  regardless of how amceteis stimulated however ...  0.611111  swahili

# %%
wav2vec2_xls_r_1b_english = transform_raw_df(wav2vec2_xls_r_1b_english_raw, columns=columns, fmt="wav2vec2")
wav2vec2_xls_r_1b_english_clean = clean_and_compute_wer(wav2vec2_xls_r_1b_english)
# Out:
# (2877, 9)
# (0, 10)
# (0, 10)

# %%
print(wav2vec2_xls_r_1b_english["wer"].mean())
print(wav2vec2_xls_r_1b_english_clean["wer"].mean())
# Out:
# 0.743025983322594
# 0.6514921574251561

# %%
model_id_or_path="facebook_wav2vec2_xls_r_1b_english"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_xls_r_1b_english, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_xls_r_1b_english_clean,
                output_dir="../results/normalized")

# %%
wav2vec2_xls_r_1b_english["name"] = "facebook_wav2vec2_xls_r_1b_english"
wav2vec2_xls_r_1b_english_clean["name"] = "facebook_wav2vec2_xls_r_1b_english"

models_df = pd.concat([models_df, wav2vec2_xls_r_1b_english])
models_df_clean = pd.concat([models_df_clean, wav2vec2_xls_r_1b_english_clean])

# %% [markdown]
# ### Wav2vec2-large-960h-lv60-self

# %%
wav2vec2_large_960h_lv60_self_raw = pd.read_csv("../results/intron-open-dev-ful-facebook-wav2vec2-large-960h-lv60-self-wer-0.5944-3232.csv")
print(wav2vec2_large_960h_lv60_self_raw.shape)
wav2vec2_large_960h_lv60_self_raw.head(2)
# Out:
# (3232, 7)
#                                           audio_path  \
# 0  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...
# 1  /data/data/intron/7ce31a48-f507-4344-bc49-96de...
#
#                                                 text  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                            reference  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                          predictions  \
# 0  ensure the correct eplacement of the feeding t...
# 1  regardless of how amikitas stimulated however ...
#
#                                      predictions_raw       wer   accent
# 0  ENSURE THE CORRECT EPLACEMENT OF THE FEEDING T...  0.645161  swahili
# 1  REGARDLESS OF HOW AMIKITAS STIMULATED HOWEVER ...  0.666667  swahili

# %%
wav2vec2_large_960h_lv60_self = transform_raw_df(wav2vec2_large_960h_lv60_self_raw, columns=columns, fmt="wav2vec2")
wav2vec2_large_960h_lv60_self_clean = clean_and_compute_wer(wav2vec2_large_960h_lv60_self)
# Out:
# (2877, 9)
# (1, 10)
# (0, 10)

# %%
print(wav2vec2_large_960h_lv60_self["wer"].mean())
print(wav2vec2_large_960h_lv60_self_clean["wer"].mean())
# Out:
# 1.2229264243916067
# 0.67118697565761

# %%
model_id_or_path="facebook_wav2vec2_large_960h_lv60_self"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_large_960h_lv60_self, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_large_960h_lv60_self_clean,
                output_dir="../results/normalized")

# %%
wav2vec2_large_960h_lv60_self["name"] = "facebook_wav2vec2_large_960h_lv60_self"
wav2vec2_large_960h_lv60_self_clean["name"] = "facebook_wav2vec2_large_960h_lv60_self"

models_df = pd.concat([models_df, wav2vec2_large_960h_lv60_self])
models_df_clean = pd.concat([models_df_clean, wav2vec2_large_960h_lv60_self_clean])

# %% [markdown]
# ### Wav2vec2-large-960h

# %%
wav2vec2_large_960h_raw = pd.read_csv("../results/intron-open-dev-ful-facebook-wav2vec2-large-960h-wer-0.7031-3232.csv")
print(wav2vec2_large_960h_raw.shape)
wav2vec2_large_960h_raw.head(2)
# Out:
# (3232, 7)
#                                           audio_path  \
# 0  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...
# 1  /data/data/intron/7ce31a48-f507-4344-bc49-96de...
#
#                                                 text  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                            reference  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                          predictions  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardless of how amercitis stimulated however...
#
#                                      predictions_raw       wer   accent
# 0  ENSURE THE CORRECT PLACEMENT OF THE FEEDING TU...  0.741935  swahili
# 1  REGARDLESS OF HOW AMERCITIS STIMULATED HOWEVER...  0.666667  swahili

# %%
wav2vec2_large_960h = transform_raw_df(wav2vec2_large_960h_raw, columns=columns, fmt="wav2vec2")
wav2vec2_large_960h_clean = clean_and_compute_wer(wav2vec2_large_960h)
# Out:
# (2877, 9)
# (1, 10)
# (0, 10)

# %%
print(wav2vec2_large_960h["wer"].mean())
print(wav2vec2_large_960h_clean["wer"].mean())
# Out:
# 1.246550763360166
# 0.789551281262618

# %%
model_id_or_path="facebook_wav2vec2_large_960h"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_large_960h, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_large_960h_clean,
                output_dir="../results/normalized")

# %%
wav2vec2_large_960h["name"] = "facebook_wav2vec2_large_960h"
wav2vec2_large_960h_clean["name"] = "facebook_wav2vec2_large_960h"

models_df = pd.concat([models_df, wav2vec2_large_960h])
models_df_clean = pd.concat([models_df_clean, wav2vec2_large_960h_clean])

# %% [markdown]
# ### Wav2vec2-large-robust-ft-swbd-300h

# %%
wav2vec2_large_robust_ft_swbd_300h_raw = pd.read_csv("../results/intron-open-dev-ful-facebook-wav2vec2-large-robust-ft-swbd-300h-wer-0.7749-3232.csv")
print(wav2vec2_large_robust_ft_swbd_300h_raw.shape)
wav2vec2_large_robust_ft_swbd_300h_raw.head(2)
# Out:
# (3232, 7)
#                                           audio_path  \
# 0  /data/data/intron/e809b58c-4f05-4754-b98c-fbf2...
# 1  /data/data/intron/7ce31a48-f507-4344-bc49-96de...
#
#                                                 text  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                            reference  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated,however...
#
#                                          predictions  \
# 0  ensure the corextplacement of the feoding tube...
# 1  regardless of how amercatis stimulated however...
#
#                                      predictions_raw       wer   accent
# 0  ENSURE THE COREXTPLACEMENT OF THE FEODING TUBE...  0.838710  swahili
# 1  REGARDLESS OF HOW AMERCATIS STIMULATED HOWEVER...  0.777778  swahili

# %%
wav2vec2_large_robust_ft_swbd_300h = transform_raw_df(wav2vec2_large_robust_ft_swbd_300h_raw, columns=columns, fmt="wav2vec2")
wav2vec2_large_robust_ft_swbd_300h_clean = clean_and_compute_wer(wav2vec2_large_robust_ft_swbd_300h)
# Out:
# (2877, 9)
# (7, 10)
# (0, 10)

# %%
print(wav2vec2_large_robust_ft_swbd_300h["wer"].mean())
print(wav2vec2_large_robust_ft_swbd_300h_clean["wer"].mean())
# Out:
# 1.2880591945755344
# 0.8636325335980687

# %%
model_id_or_path="facebook_wav2vec2_large_robust_ft_swbd_300h"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_large_robust_ft_swbd_300h, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=wav2vec2_large_robust_ft_swbd_300h_clean,
                output_dir="../results/normalized")

# %%
wav2vec2_large_robust_ft_swbd_300h["name"] = "facebook_wav2vec2_large_robust_ft_swbd_300h"
wav2vec2_large_robust_ft_swbd_300h_clean["name"] = "facebook_wav2vec2_large_robust_ft_swbd_300h"

models_df = pd.concat([models_df, wav2vec2_large_robust_ft_swbd_300h])
models_df_clean = pd.concat([models_df_clean, wav2vec2_large_robust_ft_swbd_300h_clean])

# %% [markdown]
# ### Hubert-large-ls960-ft

# %%
hubert_large_ls960_ft_raw = pd.read_csv("../results/hubert_wer_asr_dev.csv")
print(hubert_large_ls960_ft_raw.shape)
hubert_large_ls960_ft_raw.head(2)
# Out:
# (3232, 10)
#    Unnamed: 0     idx                          user_ids  \
# 0           0   72663  f559cb4f16bc465ea44b56a8d3b5513e
# 1           1  153902  2be9bc423e70a24c703f8336e60af3f3
#
#                                           transcript  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                         hubert_large  \
# 0  ENSURE THE CORRECT PLACEMENT OF THE FIDING TUB...
# 1  REGARDLESS OF HOW AMECITIS STIMULATED HOWEVER ...
#
#                                        hubert_xlarge       wer  \
# 0  ENSURE THE CORRECT PLACEMENT OF THE FEEDING TU...  0.677419
# 1  REGARDLESS OF HOW A MCIT IS STIMULATED HOWEVER...  0.722222
#
#                                   cleanup_references  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated however...
#
#                                       cleanup_hubert  wer_cleanup
# 0  ensure the correct placement of the fiding tub...     0.580645
# 1  regardless of how amecitis stimulated however ...     0.500000

# %%
hubert_large_ls960_ft = transform_raw_df(hubert_large_ls960_ft_raw, columns=columns, fmt="hubert_large")
hubert_large_ls960_ft_clean = clean_and_compute_wer(hubert_large_ls960_ft)
# Out:
# (2872, 9)
# (1, 10)
# (0, 10)

# %%
print(hubert_large_ls960_ft["wer"].mean())
print(hubert_large_ls960_ft_clean["wer"].mean())
# Out:
# 1.2269235515829158
# 0.7085538560634761

# %%
model_id_or_path="facebook_hubert_large_ls960_ft"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=hubert_large_ls960_ft, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=hubert_large_ls960_ft_clean,
                output_dir="../results/normalized")

# %%
hubert_large_ls960_ft["name"] = "facebook_hubert_large_ls960_ft"
hubert_large_ls960_ft_clean["name"] = "facebook_hubert_large_ls960_ft"

models_df = pd.concat([models_df, hubert_large_ls960_ft])
models_df_clean = pd.concat([models_df_clean, hubert_large_ls960_ft_clean])

# %% [markdown]
# ### Hubert-xlarge-ls960-ft

# %%
hubert_xlarge_ls960_ft_raw = pd.read_csv("../results/hubert_wer_asr_dev.csv")
print(hubert_xlarge_ls960_ft_raw.shape)
hubert_xlarge_ls960_ft_raw.head(2)
# Out:
# (3232, 10)
#    Unnamed: 0     idx                          user_ids  \
# 0           0   72663  f559cb4f16bc465ea44b56a8d3b5513e
# 1           1  153902  2be9bc423e70a24c703f8336e60af3f3
#
#                                           transcript  \
# 0  Ensure the correct placement of the feeding tu...
# 1  Regardlessof how amyocyteis stimulated,however...
#
#                                         hubert_large  \
# 0  ENSURE THE CORRECT PLACEMENT OF THE FIDING TUB...
# 1  REGARDLESS OF HOW AMECITIS STIMULATED HOWEVER ...
#
#                                        hubert_xlarge       wer  \
# 0  ENSURE THE CORRECT PLACEMENT OF THE FEEDING TU...  0.677419
# 1  REGARDLESS OF HOW A MCIT IS STIMULATED HOWEVER...  0.722222
#
#                                   cleanup_references  \
# 0  ensure the correct placement of the feeding tu...
# 1  regardlessof how amyocyteis stimulated however...
#
#                                       cleanup_hubert  wer_cleanup
# 0  ensure the correct placement of the fiding tub...     0.580645
# 1  regardless of how amecitis stimulated however ...     0.500000

# %%
hubert_xlarge_ls960_ft = transform_raw_df(hubert_xlarge_ls960_ft_raw, columns=columns, fmt="hubert_xlarge")
hubert_xlarge_ls960_ft_clean = clean_and_compute_wer(hubert_xlarge_ls960_ft)
# Out:
# (2872, 9)
# (1, 10)
# (0, 10)

# %%
print(hubert_xlarge_ls960_ft["wer"].mean())
print(hubert_xlarge_ls960_ft_clean["wer"].mean())
# Out:
# 1.2361624783348384
# 0.7148852567015267

# %%
model_id_or_path="facebook_hubert_xlarge_ls960_ft"

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=hubert_xlarge_ls960_ft, 
                output_dir="../results/raw")

write_to_folder(model_id_or_path=model_id_or_path, 
                predictions_df=hubert_xlarge_ls960_ft_clean,
                output_dir="../results/normalized")

# %%
hubert_xlarge_ls960_ft["name"] = "facebook_hubert_xlarge_ls960_ft"
hubert_xlarge_ls960_ft_clean["name"] = "facebook_hubert_xlarge_ls960_ft"

models_df = pd.concat([models_df, hubert_xlarge_ls960_ft])
models_df_clean = pd.concat([models_df_clean, hubert_xlarge_ls960_ft_clean])

# %%
models_df.shape, models_df_clean.shape
# Out:
# ((60342, 12), (60342, 12))

# %%
models_df.to_csv("../results/raw/intron-open-dev-all_models.csv.csv")
models_df_clean.to_csv("../results/normalized/intron-open-dev-all_models.csv.csv")

# %% [markdown]
# # Other statistics
#
# - compute per-accent statistics
# - compute per-gender statistics
# - compute per-domain statistics
# - compute per age-group statistics

# %%
import os

if os.path.exists("../results/raw/intron-open-dev-all_models.csv"):
    models_df = pd.read_csv("../results/raw/intron-open-dev-all_models.csv")

if os.path.exists("../results/normalized/intron-open-dev-all_models.csv"):
    models_df_clean = pd.read_csv("../results/normalized/intron-open-dev-all_models.csv")

# %%
list(set(models_df.name))
# Out:
# ['openai_whisper_small_en',
#  'facebook_hubert_large_ls960_ft',
#  'openai_whisper_large',
#  'google_gcp_speech_api',
#  'facebook_wav2vec2_large_960h',
#  'facebook_wav2vec2_large_960h_lv60_self',
#  'amazon_aws_transcribe_medical_api_primary_care',
#  'openai_whisper_medium',
#  'facebook_wav2vec2_xls_r_1b_english',
#  'facebook_wav2vec2_large_xlsr_53_english',
#  'microsoft_wavlm_libri_clean_100h_large',
#  'nvidia_nemo_conformer_ctc_large',
#  'openai_whisper_small',
#  'amazon_aws_transcribe_api',
#  'microsoft_azure_speech_api',
#  'facebook_wav2vec2_large_robust_ft_swbd_300h',
#  'facebook_hubert_xlarge_ls960_ft',
#  'microsoft_wavlm_libri_clean_100h_base',
#  'nvidia_nemo_conformer_transducer_large',
#  'openai_whisper_medium_en',
#  'speechbrain_crdnn_rnnlm_librispeech']

# %%
models_mapping = {
    "amazon_aws_transcribe_api": "AWS",
    "google_gcp_speech_api": "GCP",
    "facebook_hubert_xlarge_ls960_ft": "facebook/hubert-xlarge-ls960-ft",
    "facebook_wav2vec2_large_robust_ft_swbd_300h": "facebook/wav2vec2-large-robust-ft-swbd-300h",
    "microsoft_azure_speech_api": "Azure",
    "openai_whisper_small": "openai/whisper-small",
    "openai_whisper_small_en": "openai/whisper-small-en",
    "speechbrain_crdnn_rnnlm_librispeech": "speechbrain/crdnn-rnnlm-librispeech",
    "facebook_wav2vec2_large_xlsr_53_english": "facebook/wav2vec2-large-xlsr-53-english",
    "nvidia_nemo_conformer_ctc_large": "nvidia/nemo-conformer-ctc-large",
    "nvidia_nemo_conformer_transducer_large": "nvidia/nemo-conformer-transducer-large",
    "facebook_hubert_large_ls960_ft": "facebook/hubert-large-ls960-ft",
    "openai_whisper_medium": "openai/whisper-medium",
    "microsoft_wavlm_libri_clean_100h_base": "microsoft/wavlm-libri-clean-100h-base",
    "amazon_aws_transcribe_medical_api_primary_care": "AWS [Medical] (Primary Care)",
    "facebook_wav2vec2_large_960h_lv60_self": "facebook/wav2vec2-large-960h-lv60-self",
    "openai_whisper_large": "openai/whisper-large",
    "facebook_wav2vec2_large_960h": "facebook/wav2vec2-large-960h",
    "openai_whisper_medium_en": "openai/whisper-medium-en",
    "facebook_wav2vec2_xls_r_1b_english": "facebook/wav2vec2-xls-r-1b-english",
    "microsoft_wavlm_libri_clean_100h_large": "microsoft/wavlm-libri-clean-100h-large"
}

# %%
models_df.name = models_df.name.apply(lambda x: models_mapping[x])
models_df_clean.name = models_df_clean.name.apply(lambda x: models_mapping[x])

# %%
name = "facebook"
models_df[models_df.name.str.startswith(name)].groupby(["name", "domain"])["wer"].mean().reset_index()
# Out:
#                                            name    domain       wer
# 0                facebook/hubert-large-ls960-ft  clinical  1.268739
# 1                facebook/hubert-large-ls960-ft   general  1.171576
# 2               facebook/hubert-xlarge-ls960-ft  clinical  1.281888
# 3               facebook/hubert-xlarge-ls960-ft   general  1.175639
# 4                  facebook/wav2vec2-large-960h  clinical  1.298549
# 5                  facebook/wav2vec2-large-960h   general  1.177514
# 6        facebook/wav2vec2-large-960h-lv60-self  clinical  1.261808
# 7        facebook/wav2vec2-large-960h-lv60-self   general  1.171305
# 8   facebook/wav2vec2-large-robust-ft-swbd-300h  clinical  1.340119
# 9   facebook/wav2vec2-large-robust-ft-swbd-300h   general  1.218940
# 10      facebook/wav2vec2-large-xlsr-53-english  clinical  0.794567
# 11      facebook/wav2vec2-large-xlsr-53-english   general  0.609994
# 12           facebook/wav2vec2-xls-r-1b-english  clinical  0.821028
# 13           facebook/wav2vec2-xls-r-1b-english   general  0.639466

# %%
name = "nvidia"
models_df_clean[models_df_clean.name.str.startswith(name)].groupby(["name", "domain"])["wer"].mean().reset_index()
# Out:
#                                      name    domain       wer
# 0         nvidia/nemo-conformer-ctc-large  clinical  0.613789
# 1         nvidia/nemo-conformer-ctc-large   general  0.466301
# 2  nvidia/nemo-conformer-transducer-large  clinical  0.581295
# 3  nvidia/nemo-conformer-transducer-large   general  0.449387

# %%
models_df.domain = models_df.domain.str.capitalize()
models_df_clean.domain = models_df_clean.domain.str.capitalize()

# %%
domain_df = models_df.groupby(["name", "domain"])["wer"].mean().reset_index().set_index("name").pivot(columns="domain").sort_values(("wer", "Clinical"))
domain_df = domain_df.droplevel(0, axis=1)
domain_df
# Out:
# domain                                       Clinical   General
# name
# openai/whisper-medium-en                     0.513241  0.392722
# openai/whisper-medium                        0.516791  0.395027
# openai/whisper-small-en                      0.576405  0.444674
# openai/whisper-large                         0.584156  0.397843
# openai/whisper-small                         0.591087  0.457932
# Azure                                        0.640265  0.534663
# AWS                                          0.682376  0.489211
# AWS [Medical] (Primary Care)                 0.692515  0.558258
# nvidia/nemo-conformer-transducer-large       0.714832  0.596251
# GCP                                          0.727454  0.562984
# nvidia/nemo-conformer-ctc-large              0.736474  0.597584
# facebook/wav2vec2-large-xlsr-53-english      0.794567  0.609994
# facebook/wav2vec2-xls-r-1b-english           0.821028  0.639466
# microsoft/wavlm-libri-clean-100h-large       0.908866  0.731839
# microsoft/wavlm-libri-clean-100h-base        0.970380  0.812023
# facebook/wav2vec2-large-960h-lv60-self       1.261808  1.171305
# facebook/hubert-large-ls960-ft               1.268739  1.171576
# facebook/hubert-xlarge-ls960-ft              1.281888  1.175639
# facebook/wav2vec2-large-960h                 1.298549  1.177514
# facebook/wav2vec2-large-robust-ft-swbd-300h  1.340119  1.218940
# speechbrain/crdnn-rnnlm-librispeech          1.401104  1.308147

# %%
domain_df= domain_df.merge(models_df.groupby(["name"])["wer"].mean().reset_index(), on="name")
domain_df["Both"] = domain_df["wer"]
domain_df = domain_df[["name", "Clinical", "General", "Both"]]
domain_df = domain_df.set_index("name")
domain_df = domain_df[["General", "Clinical", "Both"]].round(3)
domain_df
# Out:
#                                              General  Clinical   Both
# name
# openai/whisper-medium-en                       0.393     0.513  0.461
# openai/whisper-medium                          0.395     0.517  0.464
# openai/whisper-small-en                        0.445     0.576  0.520
# openai/whisper-large                           0.398     0.584  0.504
# openai/whisper-small                           0.458     0.591  0.534
# Azure                                          0.535     0.640  0.595
# AWS                                            0.489     0.682  0.599
# AWS [Medical] (Primary Care)                   0.558     0.693  0.635
# nvidia/nemo-conformer-transducer-large         0.596     0.715  0.664
# GCP                                            0.563     0.727  0.657
# nvidia/nemo-conformer-ctc-large                0.598     0.736  0.677
# facebook/wav2vec2-large-xlsr-53-english        0.610     0.795  0.715
# facebook/wav2vec2-xls-r-1b-english             0.639     0.821  0.743
# microsoft/wavlm-libri-clean-100h-large         0.732     0.909  0.833
# microsoft/wavlm-libri-clean-100h-base          0.812     0.970  0.902
# facebook/wav2vec2-large-960h-lv60-self         1.171     1.262  1.223
# facebook/hubert-large-ls960-ft                 1.172     1.269  1.227
# facebook/hubert-xlarge-ls960-ft                1.176     1.282  1.236
# facebook/wav2vec2-large-960h                   1.178     1.299  1.247
# facebook/wav2vec2-large-robust-ft-swbd-300h    1.219     1.340  1.288
# speechbrain/crdnn-rnnlm-librispeech            1.308     1.401  1.361

# %%
print(domain_df.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &  General &  Clinical &   Both \\
# name                                        &          &           &        \\
# \midrule
# openai/whisper-medium-en                    &    0.393 &     0.513 &  0.461 \\
# openai/whisper-medium                       &    0.395 &     0.517 &  0.464 \\
# openai/whisper-small-en                     &    0.445 &     0.576 &  0.520 \\
# openai/whisper-large                        &    0.398 &     0.584 &  0.504 \\
# openai/whisper-small                        &    0.458 &     0.591 &  0.534 \\
# Azure                                       &    0.535 &     0.640 &  0.595 \\
# AWS                                         &    0.489 &     0.682 &  0.599 \\
# AWS [Medical] (Primary Care)                &    0.558 &     0.693 &  0.635 \\
# nvidia/nemo-conformer-transducer-large      &    0.596 &     0.715 &  0.664 \\
# GCP                                         &    0.563 &     0.727 &  0.657 \\
# nvidia/nemo-conformer-ctc-large             &    0.598 &     0.736 &  0.677 \\
# facebook/wav2vec2-large-xlsr-53-english     &    0.610 &     0.795 &  0.715 \\
# facebook/wav2vec2-xls-r-1b-english          &    0.639 &     0.821 &  0.743 \\
# microsoft/wavlm-libri-clean-100h-large      &    0.732 &     0.909 &  0.833 \\
# microsoft/wavlm-libri-clean-100h-base       &    0.812 &     0.970 &  0.902 \\
# facebook/wav2vec2-large-960h-lv60-self      &    1.171 &     1.262 &  1.223 \\
# facebook/hubert-large-ls960-ft              &    1.172 &     1.269 &  1.227 \\
# facebook/hubert-xlarge-ls960-ft             &    1.176 &     1.282 &  1.236 \\
# facebook/wav2vec2-large-960h                &    1.178 &     1.299 &  1.247 \\
# facebook/wav2vec2-large-robust-ft-swbd-300h &    1.219 &     1.340 &  1.288 \\
# speechbrain/crdnn-rnnlm-librispeech         &    1.308 &     1.401 &  1.361 \\
# \bottomrule
# \end{tabular}

# %%
domain_df_clean = models_df_clean.groupby(["name", "domain"])["wer"].mean().reset_index().set_index("name").pivot(columns="domain").sort_values(("wer", "Clinical"))
domain_df_clean = domain_df_clean.droplevel(0, axis=1)
domain_df_clean
# Out:
# domain                                       Clinical   General
# name
# openai/whisper-medium                        0.389489  0.295756
# openai/whisper-medium-en                     0.408459  0.314095
# openai/whisper-small                         0.479648  0.367395
# openai/whisper-large                         0.480337  0.318953
# openai/whisper-small-en                      0.481420  0.371298
# Azure                                        0.558557  0.461920
# nvidia/nemo-conformer-transducer-large       0.581295  0.449387
# AWS                                          0.590611  0.377333
# AWS [Medical] (Primary Care)                 0.595340  0.457006
# nvidia/nemo-conformer-ctc-large              0.613789  0.466301
# GCP                                          0.668108  0.508249
# facebook/wav2vec2-large-xlsr-53-english      0.721475  0.531517
# facebook/wav2vec2-xls-r-1b-english           0.732908  0.543399
# facebook/wav2vec2-large-960h-lv60-self       0.758213  0.555646
# facebook/hubert-large-ls960-ft               0.791780  0.598394
# facebook/hubert-xlarge-ls960-ft              0.806130  0.594111
# microsoft/wavlm-libri-clean-100h-large       0.848616  0.663793
# facebook/wav2vec2-large-960h                 0.883101  0.665349
# microsoft/wavlm-libri-clean-100h-base        0.925856  0.761130
# facebook/wav2vec2-large-robust-ft-swbd-300h  0.957995  0.738351
# speechbrain/crdnn-rnnlm-librispeech          1.044089  0.886930

# %%
domain_df_clean= domain_df_clean.merge(models_df_clean.groupby(["name"])["wer"].mean().reset_index(), on="name")
domain_df_clean["Both"] = domain_df_clean["wer"]
domain_df_clean = domain_df_clean[["name", "Clinical", "General", "Both"]]
domain_df_clean = domain_df_clean.set_index("name")
domain_df_clean = domain_df_clean[["General", "Clinical", "Both"]].round(3)
domain_df_clean
# Out:
#                                              General  Clinical   Both
# name
# openai/whisper-medium                          0.296     0.389  0.349
# openai/whisper-medium-en                       0.314     0.408  0.368
# openai/whisper-small                           0.367     0.480  0.431
# openai/whisper-large                           0.319     0.480  0.411
# openai/whisper-small-en                        0.371     0.481  0.434
# Azure                                          0.462     0.559  0.517
# nvidia/nemo-conformer-transducer-large         0.449     0.581  0.525
# AWS                                            0.377     0.591  0.499
# AWS [Medical] (Primary Care)                   0.457     0.595  0.536
# nvidia/nemo-conformer-ctc-large                0.466     0.614  0.550
# GCP                                            0.508     0.668  0.599
# facebook/wav2vec2-large-xlsr-53-english        0.532     0.721  0.640
# facebook/wav2vec2-xls-r-1b-english             0.543     0.733  0.651
# facebook/wav2vec2-large-960h-lv60-self         0.556     0.758  0.671
# facebook/hubert-large-ls960-ft                 0.598     0.792  0.709
# facebook/hubert-xlarge-ls960-ft                0.594     0.806  0.715
# microsoft/wavlm-libri-clean-100h-large         0.664     0.849  0.769
# facebook/wav2vec2-large-960h                   0.665     0.883  0.790
# microsoft/wavlm-libri-clean-100h-base          0.761     0.926  0.855
# facebook/wav2vec2-large-robust-ft-swbd-300h    0.738     0.958  0.864
# speechbrain/crdnn-rnnlm-librispeech            0.887     1.044  0.976

# %%
print(domain_df_clean.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &  General &  Clinical &   Both \\
# name                                        &          &           &        \\
# \midrule
# openai/whisper-medium                       &    0.296 &     0.389 &  0.349 \\
# openai/whisper-medium-en                    &    0.314 &     0.408 &  0.368 \\
# openai/whisper-small                        &    0.367 &     0.480 &  0.431 \\
# openai/whisper-large                        &    0.319 &     0.480 &  0.411 \\
# openai/whisper-small-en                     &    0.371 &     0.481 &  0.434 \\
# Azure                                       &    0.462 &     0.559 &  0.517 \\
# nvidia/nemo-conformer-transducer-large      &    0.449 &     0.581 &  0.525 \\
# AWS                                         &    0.377 &     0.591 &  0.499 \\
# AWS [Medical] (Primary Care)                &    0.457 &     0.595 &  0.536 \\
# nvidia/nemo-conformer-ctc-large             &    0.466 &     0.614 &  0.550 \\
# GCP                                         &    0.508 &     0.668 &  0.599 \\
# facebook/wav2vec2-large-xlsr-53-english     &    0.532 &     0.721 &  0.640 \\
# facebook/wav2vec2-xls-r-1b-english          &    0.543 &     0.733 &  0.651 \\
# facebook/wav2vec2-large-960h-lv60-self      &    0.556 &     0.758 &  0.671 \\
# facebook/hubert-large-ls960-ft              &    0.598 &     0.792 &  0.709 \\
# facebook/hubert-xlarge-ls960-ft             &    0.594 &     0.806 &  0.715 \\
# microsoft/wavlm-libri-clean-100h-large      &    0.664 &     0.849 &  0.769 \\
# facebook/wav2vec2-large-960h                &    0.665 &     0.883 &  0.790 \\
# microsoft/wavlm-libri-clean-100h-base       &    0.761 &     0.926 &  0.855 \\
# facebook/wav2vec2-large-robust-ft-swbd-300h &    0.738 &     0.958 &  0.864 \\
# speechbrain/crdnn-rnnlm-librispeech         &    0.887 &     1.044 &  0.976 \\
# \bottomrule
# \end{tabular}

# %%
accent_df_clean = models_df_clean.groupby(["name", "accent"])["wer"].mean().reset_index().set_index("name").pivot(columns="accent").sort_values(("wer", "english"))
accent_df_clean = accent_df_clean.droplevel(0, axis=1)
accent_df_clean = accent_df_clean.round(3)
accent_df_clean
# Out:
# accent                                       afrikaans  akan (fante)  anaang  \
# name
# openai/whisper-medium-en                         0.198         0.534   0.190
# openai/whisper-small                             0.238         0.588   0.211
# openai/whisper-medium                            0.174         0.630   0.194
# openai/whisper-small-en                          0.259         0.624   0.252
# openai/whisper-large                             0.265         0.557   0.313
# GCP                                              0.496         0.838   0.339
# AWS [Medical] (Primary Care)                     0.436         0.723   0.352
# AWS                                              0.393         0.647   0.243
# nvidia/nemo-conformer-ctc-large                  0.396         0.678   0.328
# nvidia/nemo-conformer-transducer-large           0.326         0.616   0.393
# facebook/wav2vec2-large-xlsr-53-english          0.598         0.669   0.449
# facebook/wav2vec2-xls-r-1b-english               0.581         0.787   0.466
# facebook/wav2vec2-large-960h-lv60-self           0.550         0.762   0.420
# facebook/hubert-xlarge-ls960-ft                  0.577         0.791   0.469
# facebook/hubert-large-ls960-ft                   0.566         0.839   0.472
# microsoft/wavlm-libri-clean-100h-large           0.679         0.911   0.591
# facebook/wav2vec2-large-960h                     0.633         0.886   0.518
# microsoft/wavlm-libri-clean-100h-base            0.760         0.943   0.629
# facebook/wav2vec2-large-robust-ft-swbd-300h      0.709         0.956   0.598
# Azure                                            0.367         0.590   1.000
# speechbrain/crdnn-rnnlm-librispeech              0.706         1.157   0.690
#
# accent                                       bassa-nge/nupe  berom  ebira  \
# name
# openai/whisper-medium-en                              0.515  0.598  0.220
# openai/whisper-small                                  0.565  0.599  0.212
# openai/whisper-medium                                 0.497  0.596  0.232
# openai/whisper-small-en                               0.582  0.711  0.244
# openai/whisper-large                                  0.413  0.465  0.281
# GCP                                                   0.668  0.998  0.383
# AWS [Medical] (Primary Care)                          0.459  0.780  0.395
# AWS                                                   0.439  0.757  0.292
# nvidia/nemo-conformer-ctc-large                       0.466  0.824  0.368
# nvidia/nemo-conformer-transducer-large                0.556  0.932  0.401
# facebook/wav2vec2-large-xlsr-53-english               0.612  0.892  0.456
# facebook/wav2vec2-xls-r-1b-english                    0.618  0.983  0.501
# facebook/wav2vec2-large-960h-lv60-self                0.644  1.117  0.535
# facebook/hubert-xlarge-ls960-ft                       0.699  1.165  0.607
# facebook/hubert-large-ls960-ft                        0.544  1.145  0.553
# microsoft/wavlm-libri-clean-100h-large                0.688  1.108  0.660
# facebook/wav2vec2-large-960h                          0.745  1.273  0.590
# microsoft/wavlm-libri-clean-100h-base                 0.835  1.264  0.740
# facebook/wav2vec2-large-robust-ft-swbd-300h           0.837  1.349  0.629
# Azure                                                 1.000  1.000  0.813
# speechbrain/crdnn-rnnlm-librispeech                   0.932  1.357  0.765
#
# accent                                         edo   efik  english   esan  \
# name
# openai/whisper-medium-en                     0.663  0.525    0.503  0.604
# openai/whisper-small                         0.781  0.554    0.510  0.650
# openai/whisper-medium                        0.564  0.505    0.515  0.625
# openai/whisper-small-en                      0.718  0.542    0.516  0.665
# openai/whisper-large                         0.714  0.570    0.516  0.619
# GCP                                          0.940  0.840    0.530  0.790
# AWS [Medical] (Primary Care)                 0.706  0.696    0.548  0.848
# AWS                                          0.689  0.751    0.624  1.007
# nvidia/nemo-conformer-ctc-large              0.797  0.735    0.686  1.025
# nvidia/nemo-conformer-transducer-large       0.724  0.754    0.717  1.197
# facebook/wav2vec2-large-xlsr-53-english      0.824  0.681    0.742  0.991
# facebook/wav2vec2-xls-r-1b-english           0.920  0.761    0.759  1.019
# facebook/wav2vec2-large-960h-lv60-self       0.941  0.816    0.803  1.247
# facebook/hubert-xlarge-ls960-ft              1.003  0.817    0.813  1.323
# facebook/hubert-large-ls960-ft               1.001  0.810    0.828  1.299
# microsoft/wavlm-libri-clean-100h-large       0.991  0.839    0.832  1.335
# facebook/wav2vec2-large-960h                 0.920  0.921    0.876  1.335
# microsoft/wavlm-libri-clean-100h-base        1.033  0.971    0.938  1.196
# facebook/wav2vec2-large-robust-ft-swbd-300h  1.279  0.965    0.973  1.509
# Azure                                        1.000  0.926    1.000  1.000
# speechbrain/crdnn-rnnlm-librispeech          1.298  1.245    1.053  1.579
#
# accent                                       ...  siswati  sotho  swahili  \
# name                                         ...
# openai/whisper-medium-en                     ...    0.312  0.290    0.409
# openai/whisper-small                         ...    0.404  0.358    0.520
# openai/whisper-medium                        ...    0.345  0.289    0.386
# openai/whisper-small-en                      ...    0.386  0.383    0.508
# openai/whisper-large                         ...    0.381  0.313    0.463
# GCP                                          ...    0.665  0.573    0.594
# AWS [Medical] (Primary Care)                 ...    0.510  0.423    0.591
# AWS                                          ...    0.522  0.381    0.533
# nvidia/nemo-conformer-ctc-large              ...    0.507  0.448    0.683
# nvidia/nemo-conformer-transducer-large       ...    0.507  0.475    0.595
# facebook/wav2vec2-large-xlsr-53-english      ...    0.631  0.490    0.735
# facebook/wav2vec2-xls-r-1b-english           ...    0.608  0.553    0.764
# facebook/wav2vec2-large-960h-lv60-self       ...    0.610  0.546    0.775
# facebook/hubert-xlarge-ls960-ft              ...    0.667  0.626    0.832
# facebook/hubert-large-ls960-ft               ...    0.670  0.626    0.838
# microsoft/wavlm-libri-clean-100h-large       ...    0.738  0.653    0.853
# facebook/wav2vec2-large-960h                 ...    0.768  0.684    0.942
# microsoft/wavlm-libri-clean-100h-base        ...    0.852  0.802    0.910
# facebook/wav2vec2-large-robust-ft-swbd-300h  ...    0.799  0.705    0.958
# Azure                                        ...    0.511  0.432    0.444
# speechbrain/crdnn-rnnlm-librispeech          ...    0.908  0.935    1.120
#
# accent                                         tiv  tswana    twi  urhobo  \
# name
# openai/whisper-medium-en                     0.338   0.265  0.393   0.452
# openai/whisper-small                         0.385   0.342  0.423   0.539
# openai/whisper-medium                        0.364   0.286  0.370   0.484
# openai/whisper-small-en                      0.379   0.336  0.435   0.552
# openai/whisper-large                         0.354   0.295  0.395   0.477
# GCP                                          0.588   0.420  0.561   0.787
# AWS [Medical] (Primary Care)                 0.520   0.416  0.522   0.622
# AWS                                          0.563   0.343  0.483   0.602
# nvidia/nemo-conformer-ctc-large              0.480   0.433  0.573   0.626
# nvidia/nemo-conformer-transducer-large       0.439   0.412  0.527   0.607
# facebook/wav2vec2-large-xlsr-53-english      0.628   0.519  0.628   0.726
# facebook/wav2vec2-xls-r-1b-english           0.622   0.500  0.660   0.734
# facebook/wav2vec2-large-960h-lv60-self       0.616   0.511  0.648   0.703
# facebook/hubert-xlarge-ls960-ft              0.615   0.550  0.697   0.799
# facebook/hubert-large-ls960-ft               0.647   0.564  0.677   0.805
# microsoft/wavlm-libri-clean-100h-large       0.740   0.621  0.749   0.842
# facebook/wav2vec2-large-960h                 0.686   0.569  0.760   0.855
# microsoft/wavlm-libri-clean-100h-base        0.810   0.675  0.828   0.965
# facebook/wav2vec2-large-robust-ft-swbd-300h  0.847   0.642  0.847   0.931
# Azure                                        1.000   0.390  0.416   0.942
# speechbrain/crdnn-rnnlm-librispeech          0.872   0.752  0.942   1.022
#
# accent                                       xhosa  yoruba   zulu
# name
# openai/whisper-medium-en                     0.197   0.406  0.243
# openai/whisper-small                         0.265   0.443  0.298
# openai/whisper-medium                        0.223   0.392  0.251
# openai/whisper-small-en                      0.224   0.490  0.285
# openai/whisper-large                         0.337   0.470  0.330
# GCP                                          0.648   0.662  0.522
# AWS [Medical] (Primary Care)                 0.455   0.571  0.430
# AWS                                          0.432   0.548  0.398
# nvidia/nemo-conformer-ctc-large              0.356   0.593  0.396
# nvidia/nemo-conformer-transducer-large       0.355   0.594  0.367
# facebook/wav2vec2-large-xlsr-53-english      0.457   0.674  0.525
# facebook/wav2vec2-xls-r-1b-english           0.461   0.710  0.511
# facebook/wav2vec2-large-960h-lv60-self       0.508   0.742  0.538
# facebook/hubert-xlarge-ls960-ft              0.512   0.775  0.573
# facebook/hubert-large-ls960-ft               0.518   0.775  0.571
# microsoft/wavlm-libri-clean-100h-large       0.650   0.834  0.633
# facebook/wav2vec2-large-960h                 0.597   0.839  0.650
# microsoft/wavlm-libri-clean-100h-base        0.703   0.919  0.731
# facebook/wav2vec2-large-robust-ft-swbd-300h  0.656   0.954  0.698
# Azure                                        0.456   0.464  0.354
# speechbrain/crdnn-rnnlm-librispeech          0.726   1.060  0.764
#
# [21 rows x 45 columns]

# %%
accent_df_clean.T
# Out:
# name            openai/whisper-medium-en  openai/whisper-small  \
# accent
# afrikaans                          0.198                 0.238
# akan (fante)                       0.534                 0.588
# anaang                             0.190                 0.211
# bassa-nge/nupe                     0.515                 0.565
# berom                              0.598                 0.599
# ebira                              0.220                 0.212
# edo                                0.663                 0.781
# efik                               0.525                 0.554
# english                            0.503                 0.510
# esan                               0.604                 0.650
# hausa                              0.586                 0.708
# ibibio                             0.248                 0.312
# idoma                              0.512                 0.569
# igbo                               0.382                 0.494
# ijaw                               0.429                 0.484
# ika                                0.173                 0.224
# ikwere                             0.327                 0.377
# isixhosa                           0.372                 0.358
# isizulu                            0.282                 0.365
# isoko                              0.494                 0.502
# itsekiri                           0.373                 0.374
# izon                               0.408                 0.350
# kanuri                             1.046                 1.068
# kikuyu                             0.485                 0.529
# kinyarwanda                        0.412                 0.505
# luganda                            0.231                 0.275
# luo                                0.346                 0.382
# nembe                              0.710                 0.641
# nupe                               0.536                 0.618
# ogbia                              0.712                 0.800
# pidgin                             0.658                 0.689
# sepedi                             0.362                 0.353
# sesotho                            0.256                 0.285
# setswana                           0.252                 0.356
# shona                              0.268                 0.386
# siswati                            0.312                 0.404
# sotho                              0.290                 0.358
# swahili                            0.409                 0.520
# tiv                                0.338                 0.385
# tswana                             0.265                 0.342
# twi                                0.393                 0.423
# urhobo                             0.452                 0.539
# xhosa                              0.197                 0.265
# yoruba                             0.406                 0.443
# zulu                               0.243                 0.298
#
# name            openai/whisper-medium  openai/whisper-small-en  \
# accent
# afrikaans                       0.174                    0.259
# akan (fante)                    0.630                    0.624
# anaang                          0.194                    0.252
# bassa-nge/nupe                  0.497                    0.582
# berom                           0.596                    0.711
# ebira                           0.232                    0.244
# edo                             0.564                    0.718
# efik                            0.505                    0.542
# english                         0.515                    0.516
# esan                            0.625                    0.665
# hausa                           0.564                    0.646
# ibibio                          0.254                    0.331
# idoma                           0.480                    0.604
# igbo                            0.371                    0.475
# ijaw                            0.382                    0.475
# ika                             0.141                    0.204
# ikwere                          0.296                    0.414
# isixhosa                        0.355                    0.327
# isizulu                         0.268                    0.352
# isoko                           0.437                    0.491
# itsekiri                        0.295                    0.481
# izon                            0.329                    0.462
# kanuri                          0.769                    1.018
# kikuyu                          0.419                    0.561
# kinyarwanda                     0.340                    0.491
# luganda                         0.226                    0.291
# luo                             0.278                    0.456
# nembe                           0.610                    0.589
# nupe                            0.434                    0.663
# ogbia                           0.678                    0.671
# pidgin                          0.554                    0.648
# sepedi                          0.310                    0.428
# sesotho                         0.257                    0.277
# setswana                        0.229                    0.289
# shona                           0.274                    0.422
# siswati                         0.345                    0.386
# sotho                           0.289                    0.383
# swahili                         0.386                    0.508
# tiv                             0.364                    0.379
# tswana                          0.286                    0.336
# twi                             0.370                    0.435
# urhobo                          0.484                    0.552
# xhosa                           0.223                    0.224
# yoruba                          0.392                    0.490
# zulu                            0.251                    0.285
#
# name            openai/whisper-large    GCP  AWS [Medical] (Primary Care)  \
# accent
# afrikaans                      0.265  0.496                         0.436
# akan (fante)                   0.557  0.838                         0.723
# anaang                         0.313  0.339                         0.352
# bassa-nge/nupe                 0.413  0.668                         0.459
# berom                          0.465  0.998                         0.780
# ebira                          0.281  0.383                         0.395
# edo                            0.714  0.940                         0.706
# efik                           0.570  0.840                         0.696
# english                        0.516  0.530                         0.548
# esan                           0.619  0.790                         0.848
# hausa                          0.540  0.776                         0.766
# ibibio                         0.324  0.557                         0.436
# idoma                          0.483  0.711                         0.717
# igbo                           0.431  0.599                         0.553
# ijaw                           0.422  0.667                         0.591
# ika                            0.447  0.633                         0.586
# ikwere                         0.319  0.492                         0.456
# isixhosa                       0.359  0.612                         0.540
# isizulu                        0.338  0.477                         0.436
# isoko                          0.354  0.807                         0.499
# itsekiri                       0.307  0.619                         0.530
# izon                           0.437  0.480                         0.518
# kanuri                         1.151  0.915                         0.955
# kikuyu                         0.433  0.654                         0.506
# kinyarwanda                    0.414  0.803                         0.533
# luganda                        0.249  0.509                         0.391
# luo                            0.411  0.611                         0.597
# nembe                          0.571  0.916                         0.804
# nupe                           0.476  0.743                         0.659
# ogbia                          0.706  0.787                         0.885
# pidgin                         0.511  0.716                         0.610
# sepedi                         0.436  0.572                         0.585
# sesotho                        0.313  0.529                         0.399
# setswana                       0.376  0.504                         0.452
# shona                          0.389  0.613                         0.541
# siswati                        0.381  0.665                         0.510
# sotho                          0.313  0.573                         0.423
# swahili                        0.463  0.594                         0.591
# tiv                            0.354  0.588                         0.520
# tswana                         0.295  0.420                         0.416
# twi                            0.395  0.561                         0.522
# urhobo                         0.477  0.787                         0.622
# xhosa                          0.337  0.648                         0.455
# yoruba                         0.470  0.662                         0.571
# zulu                           0.330  0.522                         0.430
#
# name              AWS  nvidia/nemo-conformer-ctc-large  \
# accent
# afrikaans       0.393                            0.396
# akan (fante)    0.647                            0.678
# anaang          0.243                            0.328
# bassa-nge/nupe  0.439                            0.466
# berom           0.757                            0.824
# ebira           0.292                            0.368
# edo             0.689                            0.797
# efik            0.751                            0.735
# english         0.624                            0.686
# esan            1.007                            1.025
# hausa           0.757                            0.859
# ibibio          0.351                            0.423
# idoma           0.675                            0.770
# igbo            0.520                            0.584
# ijaw            0.505                            0.646
# ika             0.597                            0.402
# ikwere          0.344                            0.396
# isixhosa        0.530                            0.524
# isizulu         0.412                            0.463
# isoko           0.371                            0.564
# itsekiri        0.398                            0.561
# izon            0.387                            0.477
# kanuri          0.887                            0.928
# kikuyu          0.512                            0.599
# kinyarwanda     0.540                            0.525
# luganda         0.336                            0.398
# luo             0.538                            0.586
# nembe           0.894                            0.848
# nupe            0.586                            0.581
# ogbia           0.742                            0.852
# pidgin          0.691                            0.784
# sepedi          0.498                            0.496
# sesotho         0.373                            0.419
# setswana        0.416                            0.396
# shona           0.542                            0.514
# siswati         0.522                            0.507
# sotho           0.381                            0.448
# swahili         0.533                            0.683
# tiv             0.563                            0.480
# tswana          0.343                            0.433
# twi             0.483                            0.573
# urhobo          0.602                            0.626
# xhosa           0.432                            0.356
# yoruba          0.548                            0.593
# zulu            0.398                            0.396
#
# name            nvidia/nemo-conformer-transducer-large  ...  \
# accent                                                  ...
# afrikaans                                        0.326  ...
# akan (fante)                                     0.616  ...
# anaang                                           0.393  ...
# bassa-nge/nupe                                   0.556  ...
# berom                                            0.932  ...
# ebira                                            0.401  ...
# edo                                              0.724  ...
# efik                                             0.754  ...
# english                                          0.717  ...
# esan                                             1.197  ...
# hausa                                            0.887  ...
# ibibio                                           0.412  ...
# idoma                                            0.696  ...
# igbo                                             0.576  ...
# ijaw                                             0.591  ...
# ika                                              0.424  ...
# ikwere                                           0.382  ...
# isixhosa                                         0.521  ...
# isizulu                                          0.433  ...
# isoko                                            0.536  ...
# itsekiri                                         0.558  ...
# izon                                             0.501  ...
# kanuri                                           0.875  ...
# kikuyu                                           0.613  ...
# kinyarwanda                                      0.573  ...
# luganda                                          0.386  ...
# luo                                              0.491  ...
# nembe                                            0.870  ...
# nupe                                             0.553  ...
# ogbia                                            0.768  ...
# pidgin                                           0.880  ...
# sepedi                                           0.453  ...
# sesotho                                          0.354  ...
# setswana                                         0.347  ...
# shona                                            0.461  ...
# siswati                                          0.507  ...
# sotho                                            0.475  ...
# swahili                                          0.595  ...
# tiv                                              0.439  ...
# tswana                                           0.412  ...
# twi                                              0.527  ...
# urhobo                                           0.607  ...
# xhosa                                            0.355  ...
# yoruba                                           0.594  ...
# zulu                                             0.367  ...
#
# name            facebook/wav2vec2-xls-r-1b-english  \
# accent
# afrikaans                                    0.581
# akan (fante)                                 0.787
# anaang                                       0.466
# bassa-nge/nupe                               0.618
# berom                                        0.983
# ebira                                        0.501
# edo                                          0.920
# efik                                         0.761
# english                                      0.759
# esan                                         1.019
# hausa                                        0.871
# ibibio                                       0.506
# idoma                                        0.824
# igbo                                         0.666
# ijaw                                         0.772
# ika                                          0.759
# ikwere                                       0.514
# isixhosa                                     0.598
# isizulu                                      0.585
# isoko                                        0.678
# itsekiri                                     0.631
# izon                                         0.635
# kanuri                                       0.964
# kikuyu                                       0.639
# kinyarwanda                                  0.700
# luganda                                      0.501
# luo                                          0.611
# nembe                                        0.801
# nupe                                         0.692
# ogbia                                        0.910
# pidgin                                       0.770
# sepedi                                       0.647
# sesotho                                      0.433
# setswana                                     0.538
# shona                                        0.581
# siswati                                      0.608
# sotho                                        0.553
# swahili                                      0.764
# tiv                                          0.622
# tswana                                       0.500
# twi                                          0.660
# urhobo                                       0.734
# xhosa                                        0.461
# yoruba                                       0.710
# zulu                                         0.511
#
# name            facebook/wav2vec2-large-960h-lv60-self  \
# accent
# afrikaans                                        0.550
# akan (fante)                                     0.762
# anaang                                           0.420
# bassa-nge/nupe                                   0.644
# berom                                            1.117
# ebira                                            0.535
# edo                                              0.941
# efik                                             0.816
# english                                          0.803
# esan                                             1.247
# hausa                                            0.919
# ibibio                                           0.491
# idoma                                            0.881
# igbo                                             0.686
# ijaw                                             0.724
# ika                                              0.790
# ikwere                                           0.519
# isixhosa                                         0.589
# isizulu                                          0.569
# isoko                                            0.655
# itsekiri                                         0.627
# izon                                             0.624
# kanuri                                           0.894
# kikuyu                                           0.797
# kinyarwanda                                      0.666
# luganda                                          0.520
# luo                                              0.675
# nembe                                            0.907
# nupe                                             0.726
# ogbia                                            1.017
# pidgin                                           0.821
# sepedi                                           0.699
# sesotho                                          0.472
# setswana                                         0.548
# shona                                            0.695
# siswati                                          0.610
# sotho                                            0.546
# swahili                                          0.775
# tiv                                              0.616
# tswana                                           0.511
# twi                                              0.648
# urhobo                                           0.703
# xhosa                                            0.508
# yoruba                                           0.742
# zulu                                             0.538
#
# name            facebook/hubert-xlarge-ls960-ft  \
# accent
# afrikaans                                 0.577
# akan (fante)                              0.791
# anaang                                    0.469
# bassa-nge/nupe                            0.699
# berom                                     1.165
# ebira                                     0.607
# edo                                       1.003
# efik                                      0.817
# english                                   0.813
# esan                                      1.323
# hausa                                     0.958
# ibibio                                    0.634
# idoma                                     0.878
# igbo                                      0.738
# ijaw                                      0.840
# ika                                       0.833
# ikwere                                    0.594
# isixhosa                                  0.690
# isizulu                                   0.611
# isoko                                     0.692
# itsekiri                                  0.736
# izon                                      0.700
# kanuri                                    0.969
# kikuyu                                    0.789
# kinyarwanda                               0.723
# luganda                                   0.533
# luo                                       0.744
# nembe                                     1.009
# nupe                                      0.757
# ogbia                                     1.116
# pidgin                                    0.859
# sepedi                                    0.763
# sesotho                                   0.541
# setswana                                  0.564
# shona                                     0.740
# siswati                                   0.667
# sotho                                     0.626
# swahili                                   0.832
# tiv                                       0.615
# tswana                                    0.550
# twi                                       0.697
# urhobo                                    0.799
# xhosa                                     0.512
# yoruba                                    0.775
# zulu                                      0.573
#
# name            facebook/hubert-large-ls960-ft  \
# accent
# afrikaans                                0.566
# akan (fante)                             0.839
# anaang                                   0.472
# bassa-nge/nupe                           0.544
# berom                                    1.145
# ebira                                    0.553
# edo                                      1.001
# efik                                     0.810
# english                                  0.828
# esan                                     1.299
# hausa                                    0.945
# ibibio                                   0.561
# idoma                                    0.873
# igbo                                     0.733
# ijaw                                     0.783
# ika                                      0.784
# ikwere                                   0.561
# isixhosa                                 0.626
# isizulu                                  0.615
# isoko                                    0.670
# itsekiri                                 0.734
# izon                                     0.674
# kanuri                                   1.010
# kikuyu                                   0.811
# kinyarwanda                              0.754
# luganda                                  0.552
# luo                                      0.725
# nembe                                    0.937
# nupe                                     0.773
# ogbia                                    1.002
# pidgin                                   0.843
# sepedi                                   0.688
# sesotho                                  0.497
# setswana                                 0.574
# shona                                    0.699
# siswati                                  0.670
# sotho                                    0.626
# swahili                                  0.838
# tiv                                      0.647
# tswana                                   0.564
# twi                                      0.677
# urhobo                                   0.805
# xhosa                                    0.518
# yoruba                                   0.775
# zulu                                     0.571
#
# name            microsoft/wavlm-libri-clean-100h-large  \
# accent
# afrikaans                                        0.679
# akan (fante)                                     0.911
# anaang                                           0.591
# bassa-nge/nupe                                   0.688
# berom                                            1.108
# ebira                                            0.660
# edo                                              0.991
# efik                                             0.839
# english                                          0.832
# esan                                             1.335
# hausa                                            0.988
# ibibio                                           0.638
# idoma                                            0.903
# igbo                                             0.803
# ijaw                                             0.889
# ika                                              0.896
# ikwere                                           0.633
# isixhosa                                         0.703
# isizulu                                          0.707
# isoko                                            0.704
# itsekiri                                         0.712
# izon                                             0.746
# kanuri                                           0.978
# kikuyu                                           0.815
# kinyarwanda                                      0.831
# luganda                                          0.634
# luo                                              0.761
# nembe                                            0.938
# nupe                                             0.791
# ogbia                                            1.115
# pidgin                                           0.866
# sepedi                                           0.794
# sesotho                                          0.576
# setswana                                         0.660
# shona                                            0.752
# siswati                                          0.738
# sotho                                            0.653
# swahili                                          0.853
# tiv                                              0.740
# tswana                                           0.621
# twi                                              0.749
# urhobo                                           0.842
# xhosa                                            0.650
# yoruba                                           0.834
# zulu                                             0.633
#
# name            facebook/wav2vec2-large-960h  \
# accent
# afrikaans                              0.633
# akan (fante)                           0.886
# anaang                                 0.518
# bassa-nge/nupe                         0.745
# berom                                  1.273
# ebira                                  0.590
# edo                                    0.920
# efik                                   0.921
# english                                0.876
# esan                                   1.335
# hausa                                  1.030
# ibibio                                 0.623
# idoma                                  0.911
# igbo                                   0.803
# ijaw                                   0.886
# ika                                    0.848
# ikwere                                 0.656
# isixhosa                               0.735
# isizulu                                0.716
# isoko                                  0.718
# itsekiri                               0.786
# izon                                   0.744
# kanuri                                 1.124
# kikuyu                                 0.845
# kinyarwanda                            0.841
# luganda                                0.632
# luo                                    0.852
# nembe                                  0.986
# nupe                                   0.875
# ogbia                                  1.034
# pidgin                                 1.067
# sepedi                                 0.815
# sesotho                                0.525
# setswana                               0.659
# shona                                  0.873
# siswati                                0.768
# sotho                                  0.684
# swahili                                0.942
# tiv                                    0.686
# tswana                                 0.569
# twi                                    0.760
# urhobo                                 0.855
# xhosa                                  0.597
# yoruba                                 0.839
# zulu                                   0.650
#
# name            microsoft/wavlm-libri-clean-100h-base  \
# accent
# afrikaans                                       0.760
# akan (fante)                                    0.943
# anaang                                          0.629
# bassa-nge/nupe                                  0.835
# berom                                           1.264
# ebira                                           0.740
# edo                                             1.033
# efik                                            0.971
# english                                         0.938
# esan                                            1.196
# hausa                                           1.045
# ibibio                                          0.770
# idoma                                           0.981
# igbo                                            0.888
# ijaw                                            0.922
# ika                                             0.968
# ikwere                                          0.769
# isixhosa                                        0.839
# isizulu                                         0.780
# isoko                                           0.880
# itsekiri                                        0.905
# izon                                            0.865
# kanuri                                          1.092
# kikuyu                                          0.895
# kinyarwanda                                     0.954
# luganda                                         0.728
# luo                                             0.889
# nembe                                           1.009
# nupe                                            0.923
# ogbia                                           1.125
# pidgin                                          1.067
# sepedi                                          0.902
# sesotho                                         0.664
# setswana                                        0.719
# shona                                           0.900
# siswati                                         0.852
# sotho                                           0.802
# swahili                                         0.910
# tiv                                             0.810
# tswana                                          0.675
# twi                                             0.828
# urhobo                                          0.965
# xhosa                                           0.703
# yoruba                                          0.919
# zulu                                            0.731
#
# name            facebook/wav2vec2-large-robust-ft-swbd-300h  Azure  \
# accent
# afrikaans                                             0.709  0.367
# akan (fante)                                          0.956  0.590
# anaang                                                0.598  1.000
# bassa-nge/nupe                                        0.837  1.000
# berom                                                 1.349  1.000
# ebira                                                 0.629  0.813
# edo                                                   1.279  1.000
# efik                                                  0.965  0.926
# english                                               0.973  1.000
# esan                                                  1.509  1.000
# hausa                                                 1.093  0.662
# ibibio                                                0.740  0.875
# idoma                                                 1.035  0.851
# igbo                                                  0.907  0.408
# ijaw                                                  0.998  0.725
# ika                                                   0.944  1.000
# ikwere                                                0.783  0.983
# isixhosa                                              0.769  0.457
# isizulu                                               0.724  0.385
# isoko                                                 0.820  0.986
# itsekiri                                              0.884  1.000
# izon                                                  0.884  0.850
# kanuri                                                1.229  1.000
# kikuyu                                                0.934  0.403
# kinyarwanda                                           0.912  0.453
# luganda                                               0.676  0.312
# luo                                                   0.966  0.391
# nembe                                                 1.067  1.006
# nupe                                                  1.069  1.000
# ogbia                                                 1.128  1.000
# pidgin                                                0.975  1.000
# sepedi                                                0.944  0.400
# sesotho                                               0.558  0.400
# setswana                                              0.716  0.379
# shona                                                 0.946  0.412
# siswati                                               0.799  0.511
# sotho                                                 0.705  0.432
# swahili                                               0.958  0.444
# tiv                                                   0.847  1.000
# tswana                                                0.642  0.390
# twi                                                   0.847  0.416
# urhobo                                                0.931  0.942
# xhosa                                                 0.656  0.456
# yoruba                                                0.954  0.464
# zulu                                                  0.698  0.354
#
# name            speechbrain/crdnn-rnnlm-librispeech
# accent
# afrikaans                                     0.706
# akan (fante)                                  1.157
# anaang                                        0.690
# bassa-nge/nupe                                0.932
# berom                                         1.357
# ebira                                         0.765
# edo                                           1.298
# efik                                          1.245
# english                                       1.053
# esan                                          1.579
# hausa                                         1.253
# ibibio                                        0.896
# idoma                                         1.217
# igbo                                          1.037
# ijaw                                          1.042
# ika                                           0.812
# ikwere                                        0.896
# isixhosa                                      0.880
# isizulu                                       0.912
# isoko                                         1.117
# itsekiri                                      0.957
# izon                                          1.082
# kanuri                                        1.401
# kikuyu                                        1.165
# kinyarwanda                                   0.915
# luganda                                       0.799
# luo                                           1.138
# nembe                                         1.227
# nupe                                          1.175
# ogbia                                         1.165
# pidgin                                        1.209
# sepedi                                        0.930
# sesotho                                       0.704
# setswana                                      0.749
# shona                                         1.157
# siswati                                       0.908
# sotho                                         0.935
# swahili                                       1.120
# tiv                                           0.872
# tswana                                        0.752
# twi                                           0.942
# urhobo                                        1.022
# xhosa                                         0.726
# yoruba                                        1.060
# zulu                                          0.764
#
# [45 rows x 21 columns]

# %%
# models_df_best_clean = models_df_clean[models_df_clean.name == "openai/whisper-medium"]

# %%
# accent_df_best_clean = models_df_best_clean.groupby(["name", "accent", "domain"])[["wer"]].mean().reset_index()
# accent_df_best_clean
# accent_df_clean = accent_df_clean.droplevel(0, axis=1)
